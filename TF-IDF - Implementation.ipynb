# %%
import nltk
import os
import re
import math
import operator
import numpy as np
import pandas as pd

from nltk.stem import WordNetLemmatizer
from nltk.tokenize import sent_tokenize,word_tokenize
from nltk.corpus import stopwords

Stopwords = set(stopwords.words('english'))
wordlemmatizer = WordNetLemmatizer()

# %%
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\Nirusha\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %% [markdown]
# <b> Reading data

# %%
from bs4 import BeautifulSoup
import requests

subject = input("Enter the wikipedia topic to be summarised")
base_url = "https://en.wikipedia.org/wiki/"+subject
page = requests.get(base_url)

soup = BeautifulSoup(page.content,'html.parser')
paragraphs = soup.find_all('p')

content=""
for paragraph in paragraphs:
    content+=paragraph.text
# Out:
# Enter the wikipedia topic to be summarisedNatural Language Processing

# %%
content[0:1000]
# Out:
# 'Natural language processing (NLP) is a subfield of linguistics, computer science, information engineering, and artificial intelligence concerned with the interactions between computers and human (natural) languages, in particular how to program computers to process and analyze large amounts of natural language data.\nChallenges in natural language processing frequently involve speech recognition, natural language understanding, and natural language generation.\nThe history of natural language processing (NLP) generally started in the 1950s, although work can be found from earlier periods.\nIn 1950, Alan Turing published an article titled "Computing Machinery and Intelligence" which proposed what is now called the Turing test as a criterion of intelligence[clarification needed].\nThe Georgetown experiment in 1954 involved fully automatic translation of more than sixty Russian sentences into English. The authors claimed that within three or five years, machine translation would be a solved p'

# %%
from nltk.tokenize import word_tokenize,sent_tokenize
sentences = sent_tokenize(content)

# %%
sentences[:5]
# Out:
# ['Natural language processing (NLP) is a subfield of linguistics, computer science, information engineering, and artificial intelligence concerned with the interactions between computers and human (natural) languages, in particular how to program computers to process and analyze large amounts of natural language data.',
#  'Challenges in natural language processing frequently involve speech recognition, natural language understanding, and natural language generation.',
#  'The history of natural language processing (NLP) generally started in the 1950s, although work can be found from earlier periods.',
#  'In 1950, Alan Turing published an article titled "Computing Machinery and Intelligence" which proposed what is now called the Turing test as a criterion of intelligence[clarification needed].',
#  'The Georgetown experiment in 1954 involved fully automatic translation of more than sixty Russian sentences into English.']

# %%
#df = pd.read_csv("tennis_articles.csv", encoding = "ISO-8859-1")

# %%
#df.head()

# %%
#df['article_text'][0]

# %%
#sentences=[]

#for s in df['article_text']:
  #  sentences.append(sent_tokenize(s))

# %%
#sentences = [y for x in sentences for y in x] # flatten list

# %%
#sentences[0:5]

# %%
#df['article_text']

# %%
#sent_tokenize(df['article_text'][0])

# %%
len(sentences)
# Out:
# 58

# %%
clean_sentences = pd.Series(sentences).str.replace("[^a-zA-Z]", " ")

# %%
clean_sentences = [s.lower() for s in clean_sentences]

# %%
stop_words = stopwords.words('english')

# %%
def remove_stopwords(sen):
    sen_new = " ".join([i for i in sen if i not in stop_words])
    return sen_new

# %%
clean_sentences = [remove_stopwords(r.split()) for r in clean_sentences]

# %%
clean_sentences[:5]
# Out:
# ['natural language processing nlp subfield linguistics computer science information engineering artificial intelligence concerned interactions computers human natural languages particular program computers process analyze large amounts natural language data',
#  'challenges natural language processing frequently involve speech recognition natural language understanding natural language generation',
#  'history natural language processing nlp generally started although work found earlier periods',
#  'alan turing published article titled computing machinery intelligence proposed called turing test criterion intelligence clarification needed',
#  'georgetown experiment involved fully automatic translation sixty russian sentences english']

# %% [markdown]
# <b> Calculating the frequency of each word in the document

# %%
clean_sentences
# Out:
# ['natural language processing nlp subfield linguistics computer science information engineering artificial intelligence concerned interactions computers human natural languages particular program computers process analyze large amounts natural language data',
#  'challenges natural language processing frequently involve speech recognition natural language understanding natural language generation',
#  'history natural language processing nlp generally started although work found earlier periods',
#  'alan turing published article titled computing machinery intelligence proposed called turing test criterion intelligence clarification needed',
#  'georgetown experiment involved fully automatic translation sixty russian sentences english',
#  'authors claimed within three five years machine translation would solved problem',
#  'however real progress much slower alpac report found ten year long research failed fulfill expectations funding machine translation dramatically reduced',
#  'little research machine translation conducted late first statistical machine translation systems developed',
#  'notably successful natural language processing systems developed shrdlu natural language system working restricted blocks worlds restricted vocabularies eliza simulation rogerian psychotherapist written joseph weizenbaum',
#  'using almost information human thought emotion eliza sometimes provided startlingly human like interaction',
#  'patient exceeded small knowledge base eliza might provide generic response example responding head hurts say head hurts',
#  'many programmers began write conceptual ontologies structured real world information computer understandable data',
#  'examples margie schank sam cullingford pam wilensky talespin meehan qualm lehnert politics carbonell plot units lehnert',
#  'time many chatterbots written including parry racter jabberwacky',
#  'natural language processing systems based complex sets hand written rules',
#  'starting late however revolution natural language processing introduction machine learning algorithms language processing',
#  'due steady increase computational power see moore law gradual lessening dominance chomskyan theories linguistics e g',
#  'transformational grammar whose theoretical underpinnings discouraged sort corpus linguistics underlies machine learning approach language processing',
#  'earliest used machine learning algorithms decision trees produced systems hard rules similar existing hand written rules',
#  'however part speech tagging introduced use hidden markov models natural language processing increasingly research focused statistical models make soft probabilistic decisions based attaching real valued weights features making input data',
#  'cache language models upon many speech recognition systems rely examples statistical models',
#  'models generally robust given unfamiliar input especially input contains errors common real world data produce reliable results integrated larger system comprising multiple subtasks',
#  'many notable early successes occurred field machine translation due especially work ibm research successively complicated statistical models developed',
#  'systems able take advantage existing multilingual textual corpora produced parliament canada european union result laws calling translation governmental proceedings official languages corresponding systems government',
#  'however systems depended corpora specifically developed tasks implemented systems often continues major limitation success systems',
#  'result great deal research gone methods effectively learning limited amounts data',
#  'recent research increasingly focused unsupervised semi supervised learning algorithms',
#  'algorithms learn data hand annotated desired answers using combination annotated non annotated data',
#  'generally task much difficult supervised learning typically produces less accurate results given amount input data',
#  'however enormous amount non annotated data available including among things entire content world wide web often make inferior results algorithm used low enough time complexity practical',
#  'representation learning deep neural network style machine learning methods became widespread natural language processing due part flurry results showing techniques achieve state art results many natural language tasks example language modeling parsing many others',
#  'popular techniques include use word embeddings capture semantic properties words increase end end learning higher level task e g question answering instead relying pipeline separate intermediate tasks e g part speech tagging dependency parsing',
#  'areas shift entailed substantial changes nlp systems designed deep neural network based approaches may viewed new paradigm distinct statistical natural language processing',
#  'instance term neural machine translation nmt emphasizes fact deep learning based approaches machine translation directly learn sequence sequence transformations obviating need intermediate steps word alignment language modeling used statistical machine translation smt',
#  'early days many language processing systems designed hand coding set rules writing grammars devising heuristic rules stemming',
#  'since called statistical revolution late mid much natural language processing research relied heavily machine learning',
#  'machine learning paradigm calls instead using statistical inference automatically learn rules analysis large corpora plural form corpus set documents possibly human computer annotations typical real world examples',
#  'many different classes machine learning algorithms applied natural language processing tasks',
#  'algorithms take input large set features generated input data',
#  'earliest used algorithms decision trees produced systems hard rules similar systems handwritten rules common',
#  'increasingly however research focused statistical models make soft probabilistic decisions based attaching real valued weights input feature',
#  'models advantage express relative certainty many different possible answers rather one producing reliable results model included component larger system',
#  'systems based machine learning algorithms many advantages hand produced rules following list commonly researched tasks natural language processing',
#  'tasks direct real world applications others commonly serve subtasks used aid solving larger tasks',
#  'though natural language processing tasks closely intertwined frequently subdivided categories convenience',
#  'coarse division given',
#  'first published work artificial intelligence published road marketed novel contains sixty million words',
#  'cognition refers mental action process acquiring knowledge understanding thought experience senses',
#  'cognitive science interdisciplinary scientific study mind processes',
#  'cognitive linguistics interdisciplinary branch linguistics combining knowledge research psychology linguistics',
#  'george lakoff offers methodology build natural language processing nlp algorithms perspective cognitive science along findings cognitive linguistics first defining aspect cognitive task nlp application theory conceptual metaphor explained lakoff understanding one idea terms another provides idea intent author',
#  'example consider meanings english word big',
#  'used comparative big tree likely inference intent author author using word big imply statement tree physically large comparison trees authors experience',
#  'used stative verb tomorrow big day likely inference author intent big used imply importance',
#  'examples presented complete merely indicators implication idea conceptual metaphor',
#  'intent behind usages like big person remain somewhat ambiguous person cognitive nlp algorithm alike without additional information',
#  'leads second defining aspect cognitive task nlp namely probabilistic context free grammar pcfg enables cognitive nlp algorithms assign relative measures meaning word phrase sentence piece text based information presented piece text analyzed',
#  'mathematical equation algorithms presented us patent rmm relative measure meaning token block text sentence phrase word n number tokens analyzed pmm probable measure meaning based corpora n one less number tokens analyzed location token along sequence n tokens pf probability function specific language']

# %%
tokenized_words=[]
for sentence in clean_sentences:
    tokenized_words.append(nltk.word_tokenize(sentence))

# %%
tokenized_word_results=[]
for arr in tokenized_words:
    tokenized_word_results.extend(arr)

# %%
tokenized_word_results
# Out:
# ['natural',
#  'language',
#  'processing',
#  'nlp',
#  'subfield',
#  'linguistics',
#  'computer',
#  'science',
#  'information',
#  'engineering',
#  'artificial',
#  'intelligence',
#  'concerned',
#  'interactions',
#  'computers',
#  'human',
#  'natural',
#  'languages',
#  'particular',
#  'program',
#  'computers',
#  'process',
#  'analyze',
#  'large',
#  'amounts',
#  'natural',
#  'language',
#  'data',
#  'challenges',
#  'natural',
#  'language',
#  'processing',
#  'frequently',
#  'involve',
#  'speech',
#  'recognition',
#  'natural',
#  'language',
#  'understanding',
#  'natural',
#  'language',
#  'generation',
#  'history',
#  'natural',
#  'language',
#  'processing',
#  'nlp',
#  'generally',
#  'started',
#  'although',
#  'work',
#  'found',
#  'earlier',
#  'periods',
#  'alan',
#  'turing',
#  'published',
#  'article',
#  'titled',
#  'computing',
#  'machinery',
#  'intelligence',
#  'proposed',
#  'called',
#  'turing',
#  'test',
#  'criterion',
#  'intelligence',
#  'clarification',
#  'needed',
#  'georgetown',
#  'experiment',
#  'involved',
#  'fully',
#  'automatic',
#  'translation',
#  'sixty',
#  'russian',
#  'sentences',
#  'english',
#  'authors',
#  'claimed',
#  'within',
#  'three',
#  'five',
#  'years',
#  'machine',
#  'translation',
#  'would',
#  'solved',
#  'problem',
#  'however',
#  'real',
#  'progress',
#  'much',
#  'slower',
#  'alpac',
#  'report',
#  'found',
#  'ten',
#  'year',
#  'long',
#  'research',
#  'failed',
#  'fulfill',
#  'expectations',
#  'funding',
#  'machine',
#  'translation',
#  'dramatically',
#  'reduced',
#  'little',
#  'research',
#  'machine',
#  'translation',
#  'conducted',
#  'late',
#  'first',
#  'statistical',
#  'machine',
#  'translation',
#  'systems',
#  'developed',
#  'notably',
#  'successful',
#  'natural',
#  'language',
#  'processing',
#  'systems',
#  'developed',
#  'shrdlu',
#  'natural',
#  'language',
#  'system',
#  'working',
#  'restricted',
#  'blocks',
#  'worlds',
#  'restricted',
#  'vocabularies',
#  'eliza',
#  'simulation',
#  'rogerian',
#  'psychotherapist',
#  'written',
#  'joseph',
#  'weizenbaum',
#  'using',
#  'almost',
#  'information',
#  'human',
#  'thought',
#  'emotion',
#  'eliza',
#  'sometimes',
#  'provided',
#  'startlingly',
#  'human',
#  'like',
#  'interaction',
#  'patient',
#  'exceeded',
#  'small',
#  'knowledge',
#  'base',
#  'eliza',
#  'might',
#  'provide',
#  'generic',
#  'response',
#  'example',
#  'responding',
#  'head',
#  'hurts',
#  'say',
#  'head',
#  'hurts',
#  'many',
#  'programmers',
#  'began',
#  'write',
#  'conceptual',
#  'ontologies',
#  'structured',
#  'real',
#  'world',
#  'information',
#  'computer',
#  'understandable',
#  'data',
#  'examples',
#  'margie',
#  'schank',
#  'sam',
#  'cullingford',
#  'pam',
#  'wilensky',
#  'talespin',
#  'meehan',
#  'qualm',
#  'lehnert',
#  'politics',
#  'carbonell',
#  'plot',
#  'units',
#  'lehnert',
#  'time',
#  'many',
#  'chatterbots',
#  'written',
#  'including',
#  'parry',
#  'racter',
#  'jabberwacky',
#  'natural',
#  'language',
#  'processing',
#  'systems',
#  'based',
#  'complex',
#  'sets',
#  'hand',
#  'written',
#  'rules',
#  'starting',
#  'late',
#  'however',
#  'revolution',
#  'natural',
#  'language',
#  'processing',
#  'introduction',
#  'machine',
#  'learning',
#  'algorithms',
#  'language',
#  'processing',
#  'due',
#  'steady',
#  'increase',
#  'computational',
#  'power',
#  'see',
#  'moore',
#  'law',
#  'gradual',
#  'lessening',
#  'dominance',
#  'chomskyan',
#  'theories',
#  'linguistics',
#  'e',
#  'g',
#  'transformational',
#  'grammar',
#  'whose',
#  'theoretical',
#  'underpinnings',
#  'discouraged',
#  'sort',
#  'corpus',
#  'linguistics',
#  'underlies',
#  'machine',
#  'learning',
#  'approach',
#  'language',
#  'processing',
#  'earliest',
#  'used',
#  'machine',
#  'learning',
#  'algorithms',
#  'decision',
#  'trees',
#  'produced',
#  'systems',
#  'hard',
#  'rules',
#  'similar',
#  'existing',
#  'hand',
#  'written',
#  'rules',
#  'however',
#  'part',
#  'speech',
#  'tagging',
#  'introduced',
#  'use',
#  'hidden',
#  'markov',
#  'models',
#  'natural',
#  'language',
#  'processing',
#  'increasingly',
#  'research',
#  'focused',
#  'statistical',
#  'models',
#  'make',
#  'soft',
#  'probabilistic',
#  'decisions',
#  'based',
#  'attaching',
#  'real',
#  'valued',
#  'weights',
#  'features',
#  'making',
#  'input',
#  'data',
#  'cache',
#  'language',
#  'models',
#  'upon',
#  'many',
#  'speech',
#  'recognition',
#  'systems',
#  'rely',
#  'examples',
#  'statistical',
#  'models',
#  'models',
#  'generally',
#  'robust',
#  'given',
#  'unfamiliar',
#  'input',
#  'especially',
#  'input',
#  'contains',
#  'errors',
#  'common',
#  'real',
#  'world',
#  'data',
#  'produce',
#  'reliable',
#  'results',
#  'integrated',
#  'larger',
#  'system',
#  'comprising',
#  'multiple',
#  'subtasks',
#  'many',
#  'notable',
#  'early',
#  'successes',
#  'occurred',
#  'field',
#  'machine',
#  'translation',
#  'due',
#  'especially',
#  'work',
#  'ibm',
#  'research',
#  'successively',
#  'complicated',
#  'statistical',
#  'models',
#  'developed',
#  'systems',
#  'able',
#  'take',
#  'advantage',
#  'existing',
#  'multilingual',
#  'textual',
#  'corpora',
#  'produced',
#  'parliament',
#  'canada',
#  'european',
#  'union',
#  'result',
#  'laws',
#  'calling',
#  'translation',
#  'governmental',
#  'proceedings',
#  'official',
#  'languages',
#  'corresponding',
#  'systems',
#  'government',
#  'however',
#  'systems',
#  'depended',
#  'corpora',
#  'specifically',
#  'developed',
#  'tasks',
#  'implemented',
#  'systems',
#  'often',
#  'continues',
#  'major',
#  'limitation',
#  'success',
#  'systems',
#  'result',
#  'great',
#  'deal',
#  'research',
#  'gone',
#  'methods',
#  'effectively',
#  'learning',
#  'limited',
#  'amounts',
#  'data',
#  'recent',
#  'research',
#  'increasingly',
#  'focused',
#  'unsupervised',
#  'semi',
#  'supervised',
#  'learning',
#  'algorithms',
#  'algorithms',
#  'learn',
#  'data',
#  'hand',
#  'annotated',
#  'desired',
#  'answers',
#  'using',
#  'combination',
#  'annotated',
#  'non',
#  'annotated',
#  'data',
#  'generally',
#  'task',
#  'much',
#  'difficult',
#  'supervised',
#  'learning',
#  'typically',
#  'produces',
#  'less',
#  'accurate',
#  'results',
#  'given',
#  'amount',
#  'input',
#  'data',
#  'however',
#  'enormous',
#  'amount',
#  'non',
#  'annotated',
#  'data',
#  'available',
#  'including',
#  'among',
#  'things',
#  'entire',
#  'content',
#  'world',
#  'wide',
#  'web',
#  'often',
#  'make',
#  'inferior',
#  'results',
#  'algorithm',
#  'used',
#  'low',
#  'enough',
#  'time',
#  'complexity',
#  'practical',
#  'representation',
#  'learning',
#  'deep',
#  'neural',
#  'network',
#  'style',
#  'machine',
#  'learning',
#  'methods',
#  'became',
#  'widespread',
#  'natural',
#  'language',
#  'processing',
#  'due',
#  'part',
#  'flurry',
#  'results',
#  'showing',
#  'techniques',
#  'achieve',
#  'state',
#  'art',
#  'results',
#  'many',
#  'natural',
#  'language',
#  'tasks',
#  'example',
#  'language',
#  'modeling',
#  'parsing',
#  'many',
#  'others',
#  'popular',
#  'techniques',
#  'include',
#  'use',
#  'word',
#  'embeddings',
#  'capture',
#  'semantic',
#  'properties',
#  'words',
#  'increase',
#  'end',
#  'end',
#  'learning',
#  'higher',
#  'level',
#  'task',
#  'e',
#  'g',
#  'question',
#  'answering',
#  'instead',
#  'relying',
#  'pipeline',
#  'separate',
#  'intermediate',
#  'tasks',
#  'e',
#  'g',
#  'part',
#  'speech',
#  'tagging',
#  'dependency',
#  'parsing',
#  'areas',
#  'shift',
#  'entailed',
#  'substantial',
#  'changes',
#  'nlp',
#  'systems',
#  'designed',
#  'deep',
#  'neural',
#  'network',
#  'based',
#  'approaches',
#  'may',
#  'viewed',
#  'new',
#  'paradigm',
#  'distinct',
#  'statistical',
#  'natural',
#  'language',
#  'processing',
#  'instance',
#  'term',
#  'neural',
#  'machine',
#  'translation',
#  'nmt',
#  'emphasizes',
#  'fact',
#  'deep',
#  'learning',
#  'based',
#  'approaches',
#  'machine',
#  'translation',
#  'directly',
#  'learn',
#  'sequence',
#  'sequence',
#  'transformations',
#  'obviating',
#  'need',
#  'intermediate',
#  'steps',
#  'word',
#  'alignment',
#  'language',
#  'modeling',
#  'used',
#  'statistical',
#  'machine',
#  'translation',
#  'smt',
#  'early',
#  'days',
#  'many',
#  'language',
#  'processing',
#  'systems',
#  'designed',
#  'hand',
#  'coding',
#  'set',
#  'rules',
#  'writing',
#  'grammars',
#  'devising',
#  'heuristic',
#  'rules',
#  'stemming',
#  'since',
#  'called',
#  'statistical',
#  'revolution',
#  'late',
#  'mid',
#  'much',
#  'natural',
#  'language',
#  'processing',
#  'research',
#  'relied',
#  'heavily',
#  'machine',
#  'learning',
#  'machine',
#  'learning',
#  'paradigm',
#  'calls',
#  'instead',
#  'using',
#  'statistical',
#  'inference',
#  'automatically',
#  'learn',
#  'rules',
#  'analysis',
#  'large',
#  'corpora',
#  'plural',
#  'form',
#  'corpus',
#  'set',
#  'documents',
#  'possibly',
#  'human',
#  'computer',
#  'annotations',
#  'typical',
#  'real',
#  'world',
#  'examples',
#  'many',
#  'different',
#  'classes',
#  'machine',
#  'learning',
#  'algorithms',
#  'applied',
#  'natural',
#  'language',
#  'processing',
#  'tasks',
#  'algorithms',
#  'take',
#  'input',
#  'large',
#  'set',
#  'features',
#  'generated',
#  'input',
#  'data',
#  'earliest',
#  'used',
#  'algorithms',
#  'decision',
#  'trees',
#  'produced',
#  'systems',
#  'hard',
#  'rules',
#  'similar',
#  'systems',
#  'handwritten',
#  'rules',
#  'common',
#  'increasingly',
#  'however',
#  'research',
#  'focused',
#  'statistical',
#  'models',
#  'make',
#  'soft',
#  'probabilistic',
#  'decisions',
#  'based',
#  'attaching',
#  'real',
#  'valued',
#  'weights',
#  'input',
#  'feature',
#  'models',
#  'advantage',
#  'express',
#  'relative',
#  'certainty',
#  'many',
#  'different',
#  'possible',
#  'answers',
#  'rather',
#  'one',
#  'producing',
#  'reliable',
#  'results',
#  'model',
#  'included',
#  'component',
#  'larger',
#  'system',
#  'systems',
#  'based',
#  'machine',
#  'learning',
#  'algorithms',
#  'many',
#  'advantages',
#  'hand',
#  'produced',
#  'rules',
#  'following',
#  'list',
#  'commonly',
#  'researched',
#  'tasks',
#  'natural',
#  'language',
#  'processing',
#  'tasks',
#  'direct',
#  'real',
#  'world',
#  'applications',
#  'others',
#  'commonly',
#  'serve',
#  'subtasks',
#  'used',
#  'aid',
#  'solving',
#  'larger',
#  'tasks',
#  'though',
#  'natural',
#  'language',
#  'processing',
#  'tasks',
#  'closely',
#  'intertwined',
#  'frequently',
#  'subdivided',
#  'categories',
#  'convenience',
#  'coarse',
#  'division',
#  'given',
#  'first',
#  'published',
#  'work',
#  'artificial',
#  'intelligence',
#  'published',
#  'road',
#  'marketed',
#  'novel',
#  'contains',
#  'sixty',
#  'million',
#  'words',
#  'cognition',
#  'refers',
#  'mental',
#  'action',
#  'process',
#  'acquiring',
#  'knowledge',
#  'understanding',
#  'thought',
#  'experience',
#  'senses',
#  'cognitive',
#  'science',
#  'interdisciplinary',
#  'scientific',
#  'study',
#  'mind',
#  'processes',
#  'cognitive',
#  'linguistics',
#  'interdisciplinary',
#  'branch',
#  'linguistics',
#  'combining',
#  'knowledge',
#  'research',
#  'psychology',
#  'linguistics',
#  'george',
#  'lakoff',
#  'offers',
#  'methodology',
#  'build',
#  'natural',
#  'language',
#  'processing',
#  'nlp',
#  'algorithms',
#  'perspective',
#  'cognitive',
#  'science',
#  'along',
#  'findings',
#  'cognitive',
#  'linguistics',
#  'first',
#  'defining',
#  'aspect',
#  'cognitive',
#  'task',
#  'nlp',
#  'application',
#  'theory',
#  'conceptual',
#  'metaphor',
#  'explained',
#  'lakoff',
#  'understanding',
#  'one',
#  'idea',
#  'terms',
#  'another',
#  'provides',
#  'idea',
#  'intent',
#  'author',
#  'example',
#  'consider',
#  'meanings',
#  'english',
#  'word',
#  'big',
#  'used',
#  'comparative',
#  'big',
#  'tree',
#  'likely',
#  'inference',
#  'intent',
#  'author',
#  'author',
#  'using',
#  'word',
#  'big',
#  'imply',
#  'statement',
#  'tree',
#  'physically',
#  'large',
#  'comparison',
#  'trees',
#  'authors',
#  'experience',
#  'used',
#  'stative',
#  'verb',
#  'tomorrow',
#  'big',
#  'day',
#  'likely',
#  'inference',
#  'author',
#  'intent',
#  'big',
#  'used',
#  'imply',
#  'importance',
#  'examples',
#  'presented',
#  'complete',
#  'merely',
#  'indicators',
#  'implication',
#  'idea',
#  'conceptual',
#  'metaphor',
#  'intent',
#  'behind',
#  'usages',
#  'like',
#  'big',
#  'person',
#  'remain',
#  'somewhat',
#  'ambiguous',
#  'person',
#  'cognitive',
#  'nlp',
#  'algorithm',
#  'alike',
#  'without',
#  'additional',
#  'information',
#  'leads',
#  'second',
#  'defining',
#  'aspect',
#  'cognitive',
#  'task',
#  'nlp',
#  'namely',
#  'probabilistic',
#  'context',
#  'free',
#  'grammar',
#  'pcfg',
#  'enables',
#  'cognitive',
#  'nlp',
#  'algorithms',
#  'assign',
#  'relative',
#  'measures',
#  'meaning',
#  'word',
#  'phrase',
#  'sentence',
#  'piece',
#  'text',
#  'based',
#  'information',
#  'presented',
#  'piece',
#  'text',
#  'analyzed',
#  'mathematical',
#  'equation',
#  'algorithms',
#  'presented',
#  'us',
#  'patent',
#  'rmm',
#  'relative',
#  'measure',
#  'meaning',
#  'token',
#  'block',
#  'text',
#  'sentence',
#  'phrase',
#  'word',
#  'n',
#  'number',
#  'tokens',
#  'analyzed',
#  'pmm',
#  'probable',
#  'measure',
#  'meaning',
#  'based',
#  'corpora',
#  'n',
#  'one',
#  'less',
#  'number',
#  'tokens',
#  'analyzed',
#  'location',
#  'token',
#  'along',
#  'sequence',
#  'n',
#  'tokens',
#  'pf',
#  'probability',
#  'function',
#  'specific',
#  'language']

# %%
tokenized_words
# Out:
# [['natural',
#   'language',
#   'processing',
#   'nlp',
#   'subfield',
#   'linguistics',
#   'computer',
#   'science',
#   'information',
#   'engineering',
#   'artificial',
#   'intelligence',
#   'concerned',
#   'interactions',
#   'computers',
#   'human',
#   'natural',
#   'languages',
#   'particular',
#   'program',
#   'computers',
#   'process',
#   'analyze',
#   'large',
#   'amounts',
#   'natural',
#   'language',
#   'data'],
#  ['challenges',
#   'natural',
#   'language',
#   'processing',
#   'frequently',
#   'involve',
#   'speech',
#   'recognition',
#   'natural',
#   'language',
#   'understanding',
#   'natural',
#   'language',
#   'generation'],
#  ['history',
#   'natural',
#   'language',
#   'processing',
#   'nlp',
#   'generally',
#   'started',
#   'although',
#   'work',
#   'found',
#   'earlier',
#   'periods'],
#  ['alan',
#   'turing',
#   'published',
#   'article',
#   'titled',
#   'computing',
#   'machinery',
#   'intelligence',
#   'proposed',
#   'called',
#   'turing',
#   'test',
#   'criterion',
#   'intelligence',
#   'clarification',
#   'needed'],
#  ['georgetown',
#   'experiment',
#   'involved',
#   'fully',
#   'automatic',
#   'translation',
#   'sixty',
#   'russian',
#   'sentences',
#   'english'],
#  ['authors',
#   'claimed',
#   'within',
#   'three',
#   'five',
#   'years',
#   'machine',
#   'translation',
#   'would',
#   'solved',
#   'problem'],
#  ['however',
#   'real',
#   'progress',
#   'much',
#   'slower',
#   'alpac',
#   'report',
#   'found',
#   'ten',
#   'year',
#   'long',
#   'research',
#   'failed',
#   'fulfill',
#   'expectations',
#   'funding',
#   'machine',
#   'translation',
#   'dramatically',
#   'reduced'],
#  ['little',
#   'research',
#   'machine',
#   'translation',
#   'conducted',
#   'late',
#   'first',
#   'statistical',
#   'machine',
#   'translation',
#   'systems',
#   'developed'],
#  ['notably',
#   'successful',
#   'natural',
#   'language',
#   'processing',
#   'systems',
#   'developed',
#   'shrdlu',
#   'natural',
#   'language',
#   'system',
#   'working',
#   'restricted',
#   'blocks',
#   'worlds',
#   'restricted',
#   'vocabularies',
#   'eliza',
#   'simulation',
#   'rogerian',
#   'psychotherapist',
#   'written',
#   'joseph',
#   'weizenbaum'],
#  ['using',
#   'almost',
#   'information',
#   'human',
#   'thought',
#   'emotion',
#   'eliza',
#   'sometimes',
#   'provided',
#   'startlingly',
#   'human',
#   'like',
#   'interaction'],
#  ['patient',
#   'exceeded',
#   'small',
#   'knowledge',
#   'base',
#   'eliza',
#   'might',
#   'provide',
#   'generic',
#   'response',
#   'example',
#   'responding',
#   'head',
#   'hurts',
#   'say',
#   'head',
#   'hurts'],
#  ['many',
#   'programmers',
#   'began',
#   'write',
#   'conceptual',
#   'ontologies',
#   'structured',
#   'real',
#   'world',
#   'information',
#   'computer',
#   'understandable',
#   'data'],
#  ['examples',
#   'margie',
#   'schank',
#   'sam',
#   'cullingford',
#   'pam',
#   'wilensky',
#   'talespin',
#   'meehan',
#   'qualm',
#   'lehnert',
#   'politics',
#   'carbonell',
#   'plot',
#   'units',
#   'lehnert'],
#  ['time',
#   'many',
#   'chatterbots',
#   'written',
#   'including',
#   'parry',
#   'racter',
#   'jabberwacky'],
#  ['natural',
#   'language',
#   'processing',
#   'systems',
#   'based',
#   'complex',
#   'sets',
#   'hand',
#   'written',
#   'rules'],
#  ['starting',
#   'late',
#   'however',
#   'revolution',
#   'natural',
#   'language',
#   'processing',
#   'introduction',
#   'machine',
#   'learning',
#   'algorithms',
#   'language',
#   'processing'],
#  ['due',
#   'steady',
#   'increase',
#   'computational',
#   'power',
#   'see',
#   'moore',
#   'law',
#   'gradual',
#   'lessening',
#   'dominance',
#   'chomskyan',
#   'theories',
#   'linguistics',
#   'e',
#   'g'],
#  ['transformational',
#   'grammar',
#   'whose',
#   'theoretical',
#   'underpinnings',
#   'discouraged',
#   'sort',
#   'corpus',
#   'linguistics',
#   'underlies',
#   'machine',
#   'learning',
#   'approach',
#   'language',
#   'processing'],
#  ['earliest',
#   'used',
#   'machine',
#   'learning',
#   'algorithms',
#   'decision',
#   'trees',
#   'produced',
#   'systems',
#   'hard',
#   'rules',
#   'similar',
#   'existing',
#   'hand',
#   'written',
#   'rules'],
#  ['however',
#   'part',
#   'speech',
#   'tagging',
#   'introduced',
#   'use',
#   'hidden',
#   'markov',
#   'models',
#   'natural',
#   'language',
#   'processing',
#   'increasingly',
#   'research',
#   'focused',
#   'statistical',
#   'models',
#   'make',
#   'soft',
#   'probabilistic',
#   'decisions',
#   'based',
#   'attaching',
#   'real',
#   'valued',
#   'weights',
#   'features',
#   'making',
#   'input',
#   'data'],
#  ['cache',
#   'language',
#   'models',
#   'upon',
#   'many',
#   'speech',
#   'recognition',
#   'systems',
#   'rely',
#   'examples',
#   'statistical',
#   'models'],
#  ['models',
#   'generally',
#   'robust',
#   'given',
#   'unfamiliar',
#   'input',
#   'especially',
#   'input',
#   'contains',
#   'errors',
#   'common',
#   'real',
#   'world',
#   'data',
#   'produce',
#   'reliable',
#   'results',
#   'integrated',
#   'larger',
#   'system',
#   'comprising',
#   'multiple',
#   'subtasks'],
#  ['many',
#   'notable',
#   'early',
#   'successes',
#   'occurred',
#   'field',
#   'machine',
#   'translation',
#   'due',
#   'especially',
#   'work',
#   'ibm',
#   'research',
#   'successively',
#   'complicated',
#   'statistical',
#   'models',
#   'developed'],
#  ['systems',
#   'able',
#   'take',
#   'advantage',
#   'existing',
#   'multilingual',
#   'textual',
#   'corpora',
#   'produced',
#   'parliament',
#   'canada',
#   'european',
#   'union',
#   'result',
#   'laws',
#   'calling',
#   'translation',
#   'governmental',
#   'proceedings',
#   'official',
#   'languages',
#   'corresponding',
#   'systems',
#   'government'],
#  ['however',
#   'systems',
#   'depended',
#   'corpora',
#   'specifically',
#   'developed',
#   'tasks',
#   'implemented',
#   'systems',
#   'often',
#   'continues',
#   'major',
#   'limitation',
#   'success',
#   'systems'],
#  ['result',
#   'great',
#   'deal',
#   'research',
#   'gone',
#   'methods',
#   'effectively',
#   'learning',
#   'limited',
#   'amounts',
#   'data'],
#  ['recent',
#   'research',
#   'increasingly',
#   'focused',
#   'unsupervised',
#   'semi',
#   'supervised',
#   'learning',
#   'algorithms'],
#  ['algorithms',
#   'learn',
#   'data',
#   'hand',
#   'annotated',
#   'desired',
#   'answers',
#   'using',
#   'combination',
#   'annotated',
#   'non',
#   'annotated',
#   'data'],
#  ['generally',
#   'task',
#   'much',
#   'difficult',
#   'supervised',
#   'learning',
#   'typically',
#   'produces',
#   'less',
#   'accurate',
#   'results',
#   'given',
#   'amount',
#   'input',
#   'data'],
#  ['however',
#   'enormous',
#   'amount',
#   'non',
#   'annotated',
#   'data',
#   'available',
#   'including',
#   'among',
#   'things',
#   'entire',
#   'content',
#   'world',
#   'wide',
#   'web',
#   'often',
#   'make',
#   'inferior',
#   'results',
#   'algorithm',
#   'used',
#   'low',
#   'enough',
#   'time',
#   'complexity',
#   'practical'],
#  ['representation',
#   'learning',
#   'deep',
#   'neural',
#   'network',
#   'style',
#   'machine',
#   'learning',
#   'methods',
#   'became',
#   'widespread',
#   'natural',
#   'language',
#   'processing',
#   'due',
#   'part',
#   'flurry',
#   'results',
#   'showing',
#   'techniques',
#   'achieve',
#   'state',
#   'art',
#   'results',
#   'many',
#   'natural',
#   'language',
#   'tasks',
#   'example',
#   'language',
#   'modeling',
#   'parsing',
#   'many',
#   'others'],
#  ['popular',
#   'techniques',
#   'include',
#   'use',
#   'word',
#   'embeddings',
#   'capture',
#   'semantic',
#   'properties',
#   'words',
#   'increase',
#   'end',
#   'end',
#   'learning',
#   'higher',
#   'level',
#   'task',
#   'e',
#   'g',
#   'question',
#   'answering',
#   'instead',
#   'relying',
#   'pipeline',
#   'separate',
#   'intermediate',
#   'tasks',
#   'e',
#   'g',
#   'part',
#   'speech',
#   'tagging',
#   'dependency',
#   'parsing'],
#  ['areas',
#   'shift',
#   'entailed',
#   'substantial',
#   'changes',
#   'nlp',
#   'systems',
#   'designed',
#   'deep',
#   'neural',
#   'network',
#   'based',
#   'approaches',
#   'may',
#   'viewed',
#   'new',
#   'paradigm',
#   'distinct',
#   'statistical',
#   'natural',
#   'language',
#   'processing'],
#  ['instance',
#   'term',
#   'neural',
#   'machine',
#   'translation',
#   'nmt',
#   'emphasizes',
#   'fact',
#   'deep',
#   'learning',
#   'based',
#   'approaches',
#   'machine',
#   'translation',
#   'directly',
#   'learn',
#   'sequence',
#   'sequence',
#   'transformations',
#   'obviating',
#   'need',
#   'intermediate',
#   'steps',
#   'word',
#   'alignment',
#   'language',
#   'modeling',
#   'used',
#   'statistical',
#   'machine',
#   'translation',
#   'smt'],
#  ['early',
#   'days',
#   'many',
#   'language',
#   'processing',
#   'systems',
#   'designed',
#   'hand',
#   'coding',
#   'set',
#   'rules',
#   'writing',
#   'grammars',
#   'devising',
#   'heuristic',
#   'rules',
#   'stemming'],
#  ['since',
#   'called',
#   'statistical',
#   'revolution',
#   'late',
#   'mid',
#   'much',
#   'natural',
#   'language',
#   'processing',
#   'research',
#   'relied',
#   'heavily',
#   'machine',
#   'learning'],
#  ['machine',
#   'learning',
#   'paradigm',
#   'calls',
#   'instead',
#   'using',
#   'statistical',
#   'inference',
#   'automatically',
#   'learn',
#   'rules',
#   'analysis',
#   'large',
#   'corpora',
#   'plural',
#   'form',
#   'corpus',
#   'set',
#   'documents',
#   'possibly',
#   'human',
#   'computer',
#   'annotations',
#   'typical',
#   'real',
#   'world',
#   'examples'],
#  ['many',
#   'different',
#   'classes',
#   'machine',
#   'learning',
#   'algorithms',
#   'applied',
#   'natural',
#   'language',
#   'processing',
#   'tasks'],
#  ['algorithms',
#   'take',
#   'input',
#   'large',
#   'set',
#   'features',
#   'generated',
#   'input',
#   'data'],
#  ['earliest',
#   'used',
#   'algorithms',
#   'decision',
#   'trees',
#   'produced',
#   'systems',
#   'hard',
#   'rules',
#   'similar',
#   'systems',
#   'handwritten',
#   'rules',
#   'common'],
#  ['increasingly',
#   'however',
#   'research',
#   'focused',
#   'statistical',
#   'models',
#   'make',
#   'soft',
#   'probabilistic',
#   'decisions',
#   'based',
#   'attaching',
#   'real',
#   'valued',
#   'weights',
#   'input',
#   'feature'],
#  ['models',
#   'advantage',
#   'express',
#   'relative',
#   'certainty',
#   'many',
#   'different',
#   'possible',
#   'answers',
#   'rather',
#   'one',
#   'producing',
#   'reliable',
#   'results',
#   'model',
#   'included',
#   'component',
#   'larger',
#   'system'],
#  ['systems',
#   'based',
#   'machine',
#   'learning',
#   'algorithms',
#   'many',
#   'advantages',
#   'hand',
#   'produced',
#   'rules',
#   'following',
#   'list',
#   'commonly',
#   'researched',
#   'tasks',
#   'natural',
#   'language',
#   'processing'],
#  ['tasks',
#   'direct',
#   'real',
#   'world',
#   'applications',
#   'others',
#   'commonly',
#   'serve',
#   'subtasks',
#   'used',
#   'aid',
#   'solving',
#   'larger',
#   'tasks'],
#  ['though',
#   'natural',
#   'language',
#   'processing',
#   'tasks',
#   'closely',
#   'intertwined',
#   'frequently',
#   'subdivided',
#   'categories',
#   'convenience'],
#  ['coarse', 'division', 'given'],
#  ['first',
#   'published',
#   'work',
#   'artificial',
#   'intelligence',
#   'published',
#   'road',
#   'marketed',
#   'novel',
#   'contains',
#   'sixty',
#   'million',
#   'words'],
#  ['cognition',
#   'refers',
#   'mental',
#   'action',
#   'process',
#   'acquiring',
#   'knowledge',
#   'understanding',
#   'thought',
#   'experience',
#   'senses'],
#  ['cognitive',
#   'science',
#   'interdisciplinary',
#   'scientific',
#   'study',
#   'mind',
#   'processes'],
#  ['cognitive',
#   'linguistics',
#   'interdisciplinary',
#   'branch',
#   'linguistics',
#   'combining',
#   'knowledge',
#   'research',
#   'psychology',
#   'linguistics'],
#  ['george',
#   'lakoff',
#   'offers',
#   'methodology',
#   'build',
#   'natural',
#   'language',
#   'processing',
#   'nlp',
#   'algorithms',
#   'perspective',
#   'cognitive',
#   'science',
#   'along',
#   'findings',
#   'cognitive',
#   'linguistics',
#   'first',
#   'defining',
#   'aspect',
#   'cognitive',
#   'task',
#   'nlp',
#   'application',
#   'theory',
#   'conceptual',
#   'metaphor',
#   'explained',
#   'lakoff',
#   'understanding',
#   'one',
#   'idea',
#   'terms',
#   'another',
#   'provides',
#   'idea',
#   'intent',
#   'author'],
#  ['example', 'consider', 'meanings', 'english', 'word', 'big'],
#  ['used',
#   'comparative',
#   'big',
#   'tree',
#   'likely',
#   'inference',
#   'intent',
#   'author',
#   'author',
#   'using',
#   'word',
#   'big',
#   'imply',
#   'statement',
#   'tree',
#   'physically',
#   'large',
#   'comparison',
#   'trees',
#   'authors',
#   'experience'],
#  ['used',
#   'stative',
#   'verb',
#   'tomorrow',
#   'big',
#   'day',
#   'likely',
#   'inference',
#   'author',
#   'intent',
#   'big',
#   'used',
#   'imply',
#   'importance'],
#  ['examples',
#   'presented',
#   'complete',
#   'merely',
#   'indicators',
#   'implication',
#   'idea',
#   'conceptual',
#   'metaphor'],
#  ['intent',
#   'behind',
#   'usages',
#   'like',
#   'big',
#   'person',
#   'remain',
#   'somewhat',
#   'ambiguous',
#   'person',
#   'cognitive',
#   'nlp',
#   'algorithm',
#   'alike',
#   'without',
#   'additional',
#   'information'],
#  ['leads',
#   'second',
#   'defining',
#   'aspect',
#   'cognitive',
#   'task',
#   'nlp',
#   'namely',
#   'probabilistic',
#   'context',
#   'free',
#   'grammar',
#   'pcfg',
#   'enables',
#   'cognitive',
#   'nlp',
#   'algorithms',
#   'assign',
#   'relative',
#   'measures',
#   'meaning',
#   'word',
#   'phrase',
#   'sentence',
#   'piece',
#   'text',
#   'based',
#   'information',
#   'presented',
#   'piece',
#   'text',
#   'analyzed'],
#  ['mathematical',
#   'equation',
#   'algorithms',
#   'presented',
#   'us',
#   'patent',
#   'rmm',
#   'relative',
#   'measure',
#   'meaning',
#   'token',
#   'block',
#   'text',
#   'sentence',
#   'phrase',
#   'word',
#   'n',
#   'number',
#   'tokens',
#   'analyzed',
#   'pmm',
#   'probable',
#   'measure',
#   'meaning',
#   'based',
#   'corpora',
#   'n',
#   'one',
#   'less',
#   'number',
#   'tokens',
#   'analyzed',
#   'location',
#   'token',
#   'along',
#   'sequence',
#   'n',
#   'tokens',
#   'pf',
#   'probability',
#   'function',
#   'specific',
#   'language']]

# %%
def lemmatize_words(words):
    lemmatized_words = []
    for word in words:
        lemmatized_words.append(wordlemmatizer.lemmatize(word))
    return lemmatized_words

# %%
lemmatized_words = lemmatize_words(tokenized_word_results)

# %%
lemmatize_words
# Out:
# <function __main__.lemmatize_words(words)>

# %%
len(lemmatized_words)
len(tokenized_word_results)
# Out:
# 998

# %%
def freq(words):
    dict_freq = {}
    words_unique = []
    for word in words:
        if word not in words_unique:
            words_unique.append(word)
    for word in words_unique:
          dict_freq[word] = words.count(word)
    return dict_freq

# %%
word_freq = freq(tokenized_word_results)

# %%
word_freq
# Out:
# {'natural': 20,
#  'language': 26,
#  'processing': 17,
#  'nlp': 8,
#  'subfield': 1,
#  'linguistics': 7,
#  'computer': 3,
#  'science': 3,
#  'information': 5,
#  'engineering': 1,
#  'artificial': 2,
#  'intelligence': 4,
#  'concerned': 1,
#  'interactions': 1,
#  'computers': 2,
#  'human': 4,
#  'languages': 2,
#  'particular': 1,
#  'program': 1,
#  'process': 2,
#  'analyze': 1,
#  'large': 4,
#  'amounts': 2,
#  'data': 10,
#  'challenges': 1,
#  'frequently': 2,
#  'involve': 1,
#  'speech': 4,
#  'recognition': 2,
#  'understanding': 3,
#  'generation': 1,
#  'history': 1,
#  'generally': 3,
#  'started': 1,
#  'although': 1,
#  'work': 3,
#  'found': 2,
#  'earlier': 1,
#  'periods': 1,
#  'alan': 1,
#  'turing': 2,
#  'published': 3,
#  'article': 1,
#  'titled': 1,
#  'computing': 1,
#  'machinery': 1,
#  'proposed': 1,
#  'called': 2,
#  'test': 1,
#  'criterion': 1,
#  'clarification': 1,
#  'needed': 1,
#  'georgetown': 1,
#  'experiment': 1,
#  'involved': 1,
#  'fully': 1,
#  'automatic': 1,
#  'translation': 10,
#  'sixty': 2,
#  'russian': 1,
#  'sentences': 1,
#  'english': 2,
#  'authors': 2,
#  'claimed': 1,
#  'within': 1,
#  'three': 1,
#  'five': 1,
#  'years': 1,
#  'machine': 16,
#  'would': 1,
#  'solved': 1,
#  'problem': 1,
#  'however': 6,
#  'real': 7,
#  'progress': 1,
#  'much': 3,
#  'slower': 1,
#  'alpac': 1,
#  'report': 1,
#  'ten': 1,
#  'year': 1,
#  'long': 1,
#  'research': 9,
#  'failed': 1,
#  'fulfill': 1,
#  'expectations': 1,
#  'funding': 1,
#  'dramatically': 1,
#  'reduced': 1,
#  'little': 1,
#  'conducted': 1,
#  'late': 3,
#  'first': 3,
#  'statistical': 9,
#  'systems': 15,
#  'developed': 4,
#  'notably': 1,
#  'successful': 1,
#  'shrdlu': 1,
#  'system': 3,
#  'working': 1,
#  'restricted': 2,
#  'blocks': 1,
#  'worlds': 1,
#  'vocabularies': 1,
#  'eliza': 3,
#  'simulation': 1,
#  'rogerian': 1,
#  'psychotherapist': 1,
#  'written': 4,
#  'joseph': 1,
#  'weizenbaum': 1,
#  'using': 4,
#  'almost': 1,
#  'thought': 2,
#  'emotion': 1,
#  'sometimes': 1,
#  'provided': 1,
#  'startlingly': 1,
#  'like': 2,
#  'interaction': 1,
#  'patient': 1,
#  'exceeded': 1,
#  'small': 1,
#  'knowledge': 3,
#  'base': 1,
#  'might': 1,
#  'provide': 1,
#  'generic': 1,
#  'response': 1,
#  'example': 3,
#  'responding': 1,
#  'head': 2,
#  'hurts': 2,
#  'say': 1,
#  'many': 10,
#  'programmers': 1,
#  'began': 1,
#  'write': 1,
#  'conceptual': 3,
#  'ontologies': 1,
#  'structured': 1,
#  'world': 5,
#  'understandable': 1,
#  'examples': 4,
#  'margie': 1,
#  'schank': 1,
#  'sam': 1,
#  'cullingford': 1,
#  'pam': 1,
#  'wilensky': 1,
#  'talespin': 1,
#  'meehan': 1,
#  'qualm': 1,
#  'lehnert': 2,
#  'politics': 1,
#  'carbonell': 1,
#  'plot': 1,
#  'units': 1,
#  'time': 2,
#  'chatterbots': 1,
#  'including': 2,
#  'parry': 1,
#  'racter': 1,
#  'jabberwacky': 1,
#  'based': 8,
#  'complex': 1,
#  'sets': 1,
#  'hand': 5,
#  'rules': 9,
#  'starting': 1,
#  'revolution': 2,
#  'introduction': 1,
#  'learning': 14,
#  'algorithms': 11,
#  'due': 3,
#  'steady': 1,
#  'increase': 2,
#  'computational': 1,
#  'power': 1,
#  'see': 1,
#  'moore': 1,
#  'law': 1,
#  'gradual': 1,
#  'lessening': 1,
#  'dominance': 1,
#  'chomskyan': 1,
#  'theories': 1,
#  'e': 3,
#  'g': 3,
#  'transformational': 1,
#  'grammar': 2,
#  'whose': 1,
#  'theoretical': 1,
#  'underpinnings': 1,
#  'discouraged': 1,
#  'sort': 1,
#  'corpus': 2,
#  'underlies': 1,
#  'approach': 1,
#  'earliest': 2,
#  'used': 8,
#  'decision': 2,
#  'trees': 3,
#  'produced': 4,
#  'hard': 2,
#  'similar': 2,
#  'existing': 2,
#  'part': 3,
#  'tagging': 2,
#  'introduced': 1,
#  'use': 2,
#  'hidden': 1,
#  'markov': 1,
#  'models': 8,
#  'increasingly': 3,
#  'focused': 3,
#  'make': 3,
#  'soft': 2,
#  'probabilistic': 3,
#  'decisions': 2,
#  'attaching': 2,
#  'valued': 2,
#  'weights': 2,
#  'features': 2,
#  'making': 1,
#  'input': 7,
#  'cache': 1,
#  'upon': 1,
#  'rely': 1,
#  'robust': 1,
#  'given': 3,
#  'unfamiliar': 1,
#  'especially': 2,
#  'contains': 2,
#  'errors': 1,
#  'common': 2,
#  'produce': 1,
#  'reliable': 2,
#  'results': 6,
#  'integrated': 1,
#  'larger': 3,
#  'comprising': 1,
#  'multiple': 1,
#  'subtasks': 2,
#  'notable': 1,
#  'early': 2,
#  'successes': 1,
#  'occurred': 1,
#  'field': 1,
#  'ibm': 1,
#  'successively': 1,
#  'complicated': 1,
#  'able': 1,
#  'take': 2,
#  'advantage': 2,
#  'multilingual': 1,
#  'textual': 1,
#  'corpora': 4,
#  'parliament': 1,
#  'canada': 1,
#  'european': 1,
#  'union': 1,
#  'result': 2,
#  'laws': 1,
#  'calling': 1,
#  'governmental': 1,
#  'proceedings': 1,
#  'official': 1,
#  'corresponding': 1,
#  'government': 1,
#  'depended': 1,
#  'specifically': 1,
#  'tasks': 8,
#  'implemented': 1,
#  'often': 2,
#  'continues': 1,
#  'major': 1,
#  'limitation': 1,
#  'success': 1,
#  'great': 1,
#  'deal': 1,
#  'gone': 1,
#  'methods': 2,
#  'effectively': 1,
#  'limited': 1,
#  'recent': 1,
#  'unsupervised': 1,
#  'semi': 1,
#  'supervised': 2,
#  'learn': 3,
#  'annotated': 4,
#  'desired': 1,
#  'answers': 2,
#  'combination': 1,
#  'non': 2,
#  'task': 4,
#  'difficult': 1,
#  'typically': 1,
#  'produces': 1,
#  'less': 2,
#  'accurate': 1,
#  'amount': 2,
#  'enormous': 1,
#  'available': 1,
#  'among': 1,
#  'things': 1,
#  'entire': 1,
#  'content': 1,
#  'wide': 1,
#  'web': 1,
#  'inferior': 1,
#  'algorithm': 2,
#  'low': 1,
#  'enough': 1,
#  'complexity': 1,
#  'practical': 1,
#  'representation': 1,
#  'deep': 3,
#  'neural': 3,
#  'network': 2,
#  'style': 1,
#  'became': 1,
#  'widespread': 1,
#  'flurry': 1,
#  'showing': 1,
#  'techniques': 2,
#  'achieve': 1,
#  'state': 1,
#  'art': 1,
#  'modeling': 2,
#  'parsing': 2,
#  'others': 2,
#  'popular': 1,
#  'include': 1,
#  'word': 6,
#  'embeddings': 1,
#  'capture': 1,
#  'semantic': 1,
#  'properties': 1,
#  'words': 2,
#  'end': 2,
#  'higher': 1,
#  'level': 1,
#  'question': 1,
#  'answering': 1,
#  'instead': 2,
#  'relying': 1,
#  'pipeline': 1,
#  'separate': 1,
#  'intermediate': 2,
#  'dependency': 1,
#  'areas': 1,
#  'shift': 1,
#  'entailed': 1,
#  'substantial': 1,
#  'changes': 1,
#  'designed': 2,
#  'approaches': 2,
#  'may': 1,
#  'viewed': 1,
#  'new': 1,
#  'paradigm': 2,
#  'distinct': 1,
#  'instance': 1,
#  'term': 1,
#  'nmt': 1,
#  'emphasizes': 1,
#  'fact': 1,
#  'directly': 1,
#  'sequence': 3,
#  'transformations': 1,
#  'obviating': 1,
#  'need': 1,
#  'steps': 1,
#  'alignment': 1,
#  'smt': 1,
#  'days': 1,
#  'coding': 1,
#  'set': 3,
#  'writing': 1,
#  'grammars': 1,
#  'devising': 1,
#  'heuristic': 1,
#  'stemming': 1,
#  'since': 1,
#  'mid': 1,
#  'relied': 1,
#  'heavily': 1,
#  'calls': 1,
#  'inference': 3,
#  'automatically': 1,
#  'analysis': 1,
#  'plural': 1,
#  'form': 1,
#  'documents': 1,
#  'possibly': 1,
#  'annotations': 1,
#  'typical': 1,
#  'different': 2,
#  'classes': 1,
#  'applied': 1,
#  'generated': 1,
#  'handwritten': 1,
#  'feature': 1,
#  'express': 1,
#  'relative': 3,
#  'certainty': 1,
#  'possible': 1,
#  'rather': 1,
#  'one': 3,
#  'producing': 1,
#  'model': 1,
#  'included': 1,
#  'component': 1,
#  'advantages': 1,
#  'following': 1,
#  'list': 1,
#  'commonly': 2,
#  'researched': 1,
#  'direct': 1,
#  'applications': 1,
#  'serve': 1,
#  'aid': 1,
#  'solving': 1,
#  'though': 1,
#  'closely': 1,
#  'intertwined': 1,
#  'subdivided': 1,
#  'categories': 1,
#  'convenience': 1,
#  'coarse': 1,
#  'division': 1,
#  'road': 1,
#  'marketed': 1,
#  'novel': 1,
#  'million': 1,
#  'cognition': 1,
#  'refers': 1,
#  'mental': 1,
#  'action': 1,
#  'acquiring': 1,
#  'experience': 2,
#  'senses': 1,
#  'cognitive': 8,
#  'interdisciplinary': 2,
#  'scientific': 1,
#  'study': 1,
#  'mind': 1,
#  'processes': 1,
#  'branch': 1,
#  'combining': 1,
#  'psychology': 1,
#  'george': 1,
#  'lakoff': 2,
#  'offers': 1,
#  'methodology': 1,
#  'build': 1,
#  'perspective': 1,
#  'along': 2,
#  'findings': 1,
#  'defining': 2,
#  'aspect': 2,
#  'application': 1,
#  'theory': 1,
#  'metaphor': 2,
#  'explained': 1,
#  'idea': 3,
#  'terms': 1,
#  'another': 1,
#  'provides': 1,
#  'intent': 4,
#  'author': 4,
#  'consider': 1,
#  'meanings': 1,
#  'big': 6,
#  'comparative': 1,
#  'tree': 2,
#  'likely': 2,
#  'imply': 2,
#  'statement': 1,
#  'physically': 1,
#  'comparison': 1,
#  'stative': 1,
#  'verb': 1,
#  'tomorrow': 1,
#  'day': 1,
#  'importance': 1,
#  'presented': 3,
#  'complete': 1,
#  'merely': 1,
#  'indicators': 1,
#  'implication': 1,
#  'behind': 1,
#  'usages': 1,
#  'person': 2,
#  'remain': 1,
#  'somewhat': 1,
#  'ambiguous': 1,
#  'alike': 1,
#  'without': 1,
#  'additional': 1,
#  'leads': 1,
#  'second': 1,
#  'namely': 1,
#  'context': 1,
#  'free': 1,
#  'pcfg': 1,
#  'enables': 1,
#  'assign': 1,
#  'measures': 1,
#  'meaning': 3,
#  'phrase': 2,
#  'sentence': 2,
#  'piece': 2,
#  'text': 3,
#  'analyzed': 3,
#  'mathematical': 1,
#  'equation': 1,
#  'us': 1,
#  'patent': 1,
#  'rmm': 1,
#  'measure': 2,
#  'token': 2,
#  'block': 1,
#  'n': 3,
#  'number': 2,
#  'tokens': 3,
#  'pmm': 1,
#  'probable': 1,
#  'location': 1,
#  'pf': 1,
#  'probability': 1,
#  'function': 1,
#  'specific': 1}

# %%
def pos_tagging(text):
    pos_tag = nltk.pos_tag(text.split())
    pos_tagged_noun_verb = []
    for word,tag in pos_tag:
        if tag == "NN" or tag == "NNP" or tag == "NNS" or tag == "VB" or tag == "VBD" or tag == "VBG" or tag == "VBN" or tag == "VBP" or tag == "VBZ":
            pos_tagged_noun_verb.append(word)
    print(pos_tagged_noun_verb)
    return pos_tagged_noun_verb

# %%
def word_tfidf(dict_freq,word,sentences,sentence):
    word_tfidf = [] 
    tf = tf_score(word,sentence)
    idf = idf_score(len(sentences),word,sentences)
    tf_idf = tf_idf_score(tf,idf)
    return tf_idf

# %%
def tf_score(word,sentence):
    print(f'Sentence from tf_Score {sentence}, word {word}')
    freq_sum = 0
    word_frequency_in_sentence = 0
    len_sentence = len(sentence)
    for word_in_sentence in sentence.split():
        if word == word_in_sentence:
            word_frequency_in_sentence = word_frequency_in_sentence + 1
    tf =  word_frequency_in_sentence/ len_sentence
    return tf

# %%
def idf_score(no_of_sentences,word,sentences):
    no_of_sentence_containing_word = 0
    for sentence in sentences:
        #sentence = remove_special_characters(str(sentence))
        #sentence = re.sub(r'\d+', '', sentence)
        sentence = sentence.split()
        sentence = [word for word in sentence if word.lower() not in Stopwords and len(word)>1]
        sentence = [word.lower() for word in sentence]
        sentence = [wordlemmatizer.lemmatize(word) for word in sentence]
        if word in sentence:
            no_of_sentence_containing_word = no_of_sentence_containing_word + 1
    idf = math.log10(no_of_sentences/no_of_sentence_containing_word)
    return idf

# %%
def tf_idf_score(tf,idf):
    return tf*idf

# %%
clean_sentences[:2]
# Out:
# ['natural language processing nlp subfield linguistics computer science information engineering artificial intelligence concerned interactions computers human natural languages particular program computers process analyze large amounts natural language data',
#  'challenges natural language processing frequently involve speech recognition natural language understanding natural language generation']

# %%
def sentence_importance(sentence,dict_freq,sentences):
    sentence_score = 0
    pos_tagged_sentence = []
    no_of_sentences = len(sentences)
    pos_tagged_sentence = pos_tagging(sentence)
    for word in pos_tagged_sentence:
        if word.lower() not in Stopwords and word not in Stopwords    and len(word)>1:
            word = word.lower() 
            word = wordlemmatizer.lemmatize(word)
            sentence_score = sentence_score + word_tfidf(dict_freq,word,sentences,sentence)
    return sentence_score

# %%
c = 1
sentence_with_importance = {}
for sent in clean_sentences:
    sentenceimp = sentence_importance(sent,word_freq,clean_sentences)
    sentence_with_importance[c] = sentenceimp
    c = c+1
sentence_with_importance = sorted(sentence_with_importance.items(), key=operator.itemgetter(1),reverse=True)
# Out:
# ['language', 'processing', 'subfield', 'linguistics', 'computer', 'science', 'information', 'engineering', 'intelligence', 'concerned', 'interactions', 'computers', 'languages', 'program', 'computers', 'process', 'amounts', 'language', 'data']
# Sentence from tf_Score natural language processing nlp subfield linguistics computer science information engineering artificial intelligence concerned interactions computers human natural languages particular program computers process analyze large amounts natural language data, word language
# Sentence from tf_Score natural language processing nlp subfield linguistics computer science information engineering artificial intelligence concerned interactions computers human natural languages particular program computers process analyze large amounts natural language data, word processing
# Sentence from tf_Score natural language processing nlp subfield linguistics computer science information engineering artificial intelligence concerned interactions computers human natural languages particular program computers process analyze large amounts natural language data, word subfield
# Sentence from tf_Score natural language processing nlp subfield linguistics computer science information engineering artificial intelligence concerned interactions computers human natural languages particular program computers process analyze large amounts natural language data, word linguistics
# Sentence from tf_Score natural language processing nlp subfield linguistics computer science information engineering artificial intelligence concerned interactions computers human natural languages particular program computers process analyze large amounts natural language data, word computer
# Sentence from tf_Score natural language processing nlp subfield linguistics computer science information engineering artificial intelligence concerned interactions computers human natural languages particular program computers process analyze large amounts natural language data, word science
# Sentence from tf_Score natural language processing nlp subfield linguistics computer science information engineering artificial intelligence concerned interactions computers human natural languages particular program computers process analyze large amounts natural language data, word information
# Sentence from tf_Score natural language processing nlp subfield linguistics computer science information engineering artificial intelligence concerned interactions computers human natural languages particular program computers process analyze large amounts natural language data, word engineering
# Sentence from tf_Score natural language processing nlp subfield linguistics computer science information engineering artificial intelligence concerned interactions computers human natural languages particular program computers process analyze large amounts natural language data, word intelligence
# Sentence from tf_Score natural language processing nlp subfield linguistics computer science information engineering artificial intelligence concerned interactions computers human natural languages particular program computers process analyze large amounts natural language data, word concerned
# Sentence from tf_Score natural language processing nlp subfield linguistics computer science information engineering artificial intelligence concerned interactions computers human natural languages particular program computers process analyze large amounts natural language data, word interaction
# Sentence from tf_Score natural language processing nlp subfield linguistics computer science information engineering artificial intelligence concerned interactions computers human natural languages particular program computers process analyze large amounts natural language data, word computer
# Sentence from tf_Score natural language processing nlp subfield linguistics computer science information engineering artificial intelligence concerned interactions computers human natural languages particular program computers process analyze large amounts natural language data, word language
# Sentence from tf_Score natural language processing nlp subfield linguistics computer science information engineering artificial intelligence concerned interactions computers human natural languages particular program computers process analyze large amounts natural language data, word program
# Sentence from tf_Score natural language processing nlp subfield linguistics computer science information engineering artificial intelligence concerned interactions computers human natural languages particular program computers process analyze large amounts natural language data, word computer
# Sentence from tf_Score natural language processing nlp subfield linguistics computer science information engineering artificial intelligence concerned interactions computers human natural languages particular program computers process analyze large amounts natural language data, word process
# Sentence from tf_Score natural language processing nlp subfield linguistics computer science information engineering artificial intelligence concerned interactions computers human natural languages particular program computers process analyze large amounts natural language data, word amount
# Sentence from tf_Score natural language processing nlp subfield linguistics computer science information engineering artificial intelligence concerned interactions computers human natural languages particular program computers process analyze large amounts natural language data, word language
# Sentence from tf_Score natural language processing nlp subfield linguistics computer science information engineering artificial intelligence concerned interactions computers human natural languages particular program computers process analyze large amounts natural language data, word data
# ['challenges', 'language', 'processing', 'involve', 'speech', 'recognition', 'language', 'language', 'generation']
# Sentence from tf_Score challenges natural language processing frequently involve speech recognition natural language understanding natural language generation, word challenge
# Sentence from tf_Score challenges natural language processing frequently involve speech recognition natural language understanding natural language generation, word language
# Sentence from tf_Score challenges natural language processing frequently involve speech recognition natural language understanding natural language generation, word processing
# Sentence from tf_Score challenges natural language processing frequently involve speech recognition natural language understanding natural language generation, word involve
# Sentence from tf_Score challenges natural language processing frequently involve speech recognition natural language understanding natural language generation, word speech
# Sentence from tf_Score challenges natural language processing frequently involve speech recognition natural language understanding natural language generation, word recognition
# Sentence from tf_Score challenges natural language processing frequently involve speech recognition natural language understanding natural language generation, word language
# Sentence from tf_Score challenges natural language processing frequently involve speech recognition natural language understanding natural language generation, word language
# Sentence from tf_Score challenges natural language processing frequently involve speech recognition natural language understanding natural language generation, word generation
# ['history', 'language', 'processing', 'nlp', 'started', 'work', 'found', 'periods']
# Sentence from tf_Score history natural language processing nlp generally started although work found earlier periods, word history
# Sentence from tf_Score history natural language processing nlp generally started although work found earlier periods, word language
# Sentence from tf_Score history natural language processing nlp generally started although work found earlier periods, word processing
# Sentence from tf_Score history natural language processing nlp generally started although work found earlier periods, word nlp
# Sentence from tf_Score history natural language processing nlp generally started although work found earlier periods, word started
# Sentence from tf_Score history natural language processing nlp generally started although work found earlier periods, word work
# Sentence from tf_Score history natural language processing nlp generally started although work found earlier periods, word found
# Sentence from tf_Score history natural language processing nlp generally started although work found earlier periods, word period
# ['alan', 'turing', 'published', 'article', 'titled', 'computing', 'machinery', 'intelligence', 'proposed', 'called', 'turing', 'test', 'criterion', 'intelligence', 'clarification', 'needed']
# Sentence from tf_Score alan turing published article titled computing machinery intelligence proposed called turing test criterion intelligence clarification needed, word alan
# Sentence from tf_Score alan turing published article titled computing machinery intelligence proposed called turing test criterion intelligence clarification needed, word turing
# Sentence from tf_Score alan turing published article titled computing machinery intelligence proposed called turing test criterion intelligence clarification needed, word published
# Sentence from tf_Score alan turing published article titled computing machinery intelligence proposed called turing test criterion intelligence clarification needed, word article
# Sentence from tf_Score alan turing published article titled computing machinery intelligence proposed called turing test criterion intelligence clarification needed, word titled
# Sentence from tf_Score alan turing published article titled computing machinery intelligence proposed called turing test criterion intelligence clarification needed, word computing
# Sentence from tf_Score alan turing published article titled computing machinery intelligence proposed called turing test criterion intelligence clarification needed, word machinery
# Sentence from tf_Score alan turing published article titled computing machinery intelligence proposed called turing test criterion intelligence clarification needed, word intelligence
# Sentence from tf_Score alan turing published article titled computing machinery intelligence proposed called turing test criterion intelligence clarification needed, word proposed
# Sentence from tf_Score alan turing published article titled computing machinery intelligence proposed called turing test criterion intelligence clarification needed, word called
# Sentence from tf_Score alan turing published article titled computing machinery intelligence proposed called turing test criterion intelligence clarification needed, word turing
# Sentence from tf_Score alan turing published article titled computing machinery intelligence proposed called turing test criterion intelligence clarification needed, word test
# Sentence from tf_Score alan turing published article titled computing machinery intelligence proposed called turing test criterion intelligence clarification needed, word criterion
# Sentence from tf_Score alan turing published article titled computing machinery intelligence proposed called turing test criterion intelligence clarification needed, word intelligence
# Sentence from tf_Score alan turing published article titled computing machinery intelligence proposed called turing test criterion intelligence clarification needed, word clarification
# Sentence from tf_Score alan turing published article titled computing machinery intelligence proposed called turing test criterion intelligence clarification needed, word needed
# ['experiment', 'involved', 'translation', 'sixty', 'sentences', 'english']
# Sentence from tf_Score georgetown experiment involved fully automatic translation sixty russian sentences english, word experiment
# Sentence from tf_Score georgetown experiment involved fully automatic translation sixty russian sentences english, word involved
# Sentence from tf_Score georgetown experiment involved fully automatic translation sixty russian sentences english, word translation
# Sentence from tf_Score georgetown experiment involved fully automatic translation sixty russian sentences english, word sixty
# Sentence from tf_Score georgetown experiment involved fully automatic translation sixty russian sentences english, word sentence
# Sentence from tf_Score georgetown experiment involved fully automatic translation sixty russian sentences english, word english
# ['authors', 'claimed', 'years', 'machine', 'translation', 'solved', 'problem']
# Sentence from tf_Score authors claimed within three five years machine translation would solved problem, word author
# Sentence from tf_Score authors claimed within three five years machine translation would solved problem, word claimed
# Sentence from tf_Score authors claimed within three five years machine translation would solved problem, word year
# Sentence from tf_Score authors claimed within three five years machine translation would solved problem, word machine
# Sentence from tf_Score authors claimed within three five years machine translation would solved problem, word translation
# Sentence from tf_Score authors claimed within three five years machine translation would solved problem, word solved
# Sentence from tf_Score authors claimed within three five years machine translation would solved problem, word problem
# ['progress', 'report', 'found', 'year', 'research', 'failed', 'expectations', 'funding', 'machine', 'translation', 'reduced']
# Sentence from tf_Score however real progress much slower alpac report found ten year long research failed fulfill expectations funding machine translation dramatically reduced, word progress
# Sentence from tf_Score however real progress much slower alpac report found ten year long research failed fulfill expectations funding machine translation dramatically reduced, word report
# Sentence from tf_Score however real progress much slower alpac report found ten year long research failed fulfill expectations funding machine translation dramatically reduced, word found
# Sentence from tf_Score however real progress much slower alpac report found ten year long research failed fulfill expectations funding machine translation dramatically reduced, word year
# Sentence from tf_Score however real progress much slower alpac report found ten year long research failed fulfill expectations funding machine translation dramatically reduced, word research
# Sentence from tf_Score however real progress much slower alpac report found ten year long research failed fulfill expectations funding machine translation dramatically reduced, word failed
# Sentence from tf_Score however real progress much slower alpac report found ten year long research failed fulfill expectations funding machine translation dramatically reduced, word expectation
# Sentence from tf_Score however real progress much slower alpac report found ten year long research failed fulfill expectations funding machine translation dramatically reduced, word funding
# Sentence from tf_Score however real progress much slower alpac report found ten year long research failed fulfill expectations funding machine translation dramatically reduced, word machine
# Sentence from tf_Score however real progress much slower alpac report found ten year long research failed fulfill expectations funding machine translation dramatically reduced, word translation
# Sentence from tf_Score however real progress much slower alpac report found ten year long research failed fulfill expectations funding machine translation dramatically reduced, word reduced
# ['research', 'machine', 'translation', 'conducted', 'machine', 'translation', 'systems', 'developed']
# Sentence from tf_Score little research machine translation conducted late first statistical machine translation systems developed, word research
# Sentence from tf_Score little research machine translation conducted late first statistical machine translation systems developed, word machine
# Sentence from tf_Score little research machine translation conducted late first statistical machine translation systems developed, word translation
# Sentence from tf_Score little research machine translation conducted late first statistical machine translation systems developed, word conducted
# Sentence from tf_Score little research machine translation conducted late first statistical machine translation systems developed, word machine
# Sentence from tf_Score little research machine translation conducted late first statistical machine translation systems developed, word translation
# Sentence from tf_Score little research machine translation conducted late first statistical machine translation systems developed, word system
# Sentence from tf_Score little research machine translation conducted late first statistical machine translation systems developed, word developed
# ['language', 'processing', 'systems', 'developed', 'language', 'system', 'working', 'restricted', 'blocks', 'worlds', 'restricted', 'vocabularies', 'simulation', 'psychotherapist', 'written', 'joseph', 'weizenbaum']
# Sentence from tf_Score notably successful natural language processing systems developed shrdlu natural language system working restricted blocks worlds restricted vocabularies eliza simulation rogerian psychotherapist written joseph weizenbaum, word language
# Sentence from tf_Score notably successful natural language processing systems developed shrdlu natural language system working restricted blocks worlds restricted vocabularies eliza simulation rogerian psychotherapist written joseph weizenbaum, word processing
# Sentence from tf_Score notably successful natural language processing systems developed shrdlu natural language system working restricted blocks worlds restricted vocabularies eliza simulation rogerian psychotherapist written joseph weizenbaum, word system
# Sentence from tf_Score notably successful natural language processing systems developed shrdlu natural language system working restricted blocks worlds restricted vocabularies eliza simulation rogerian psychotherapist written joseph weizenbaum, word developed
# Sentence from tf_Score notably successful natural language processing systems developed shrdlu natural language system working restricted blocks worlds restricted vocabularies eliza simulation rogerian psychotherapist written joseph weizenbaum, word language
# Sentence from tf_Score notably successful natural language processing systems developed shrdlu natural language system working restricted blocks worlds restricted vocabularies eliza simulation rogerian psychotherapist written joseph weizenbaum, word system
# Sentence from tf_Score notably successful natural language processing systems developed shrdlu natural language system working restricted blocks worlds restricted vocabularies eliza simulation rogerian psychotherapist written joseph weizenbaum, word working
# Sentence from tf_Score notably successful natural language processing systems developed shrdlu natural language system working restricted blocks worlds restricted vocabularies eliza simulation rogerian psychotherapist written joseph weizenbaum, word restricted
# Sentence from tf_Score notably successful natural language processing systems developed shrdlu natural language system working restricted blocks worlds restricted vocabularies eliza simulation rogerian psychotherapist written joseph weizenbaum, word block
# Sentence from tf_Score notably successful natural language processing systems developed shrdlu natural language system working restricted blocks worlds restricted vocabularies eliza simulation rogerian psychotherapist written joseph weizenbaum, word world
# Sentence from tf_Score notably successful natural language processing systems developed shrdlu natural language system working restricted blocks worlds restricted vocabularies eliza simulation rogerian psychotherapist written joseph weizenbaum, word restricted
# Sentence from tf_Score notably successful natural language processing systems developed shrdlu natural language system working restricted blocks worlds restricted vocabularies eliza simulation rogerian psychotherapist written joseph weizenbaum, word vocabulary
# Sentence from tf_Score notably successful natural language processing systems developed shrdlu natural language system working restricted blocks worlds restricted vocabularies eliza simulation rogerian psychotherapist written joseph weizenbaum, word simulation
# Sentence from tf_Score notably successful natural language processing systems developed shrdlu natural language system working restricted blocks worlds restricted vocabularies eliza simulation rogerian psychotherapist written joseph weizenbaum, word psychotherapist
# Sentence from tf_Score notably successful natural language processing systems developed shrdlu natural language system working restricted blocks worlds restricted vocabularies eliza simulation rogerian psychotherapist written joseph weizenbaum, word written
# Sentence from tf_Score notably successful natural language processing systems developed shrdlu natural language system working restricted blocks worlds restricted vocabularies eliza simulation rogerian psychotherapist written joseph weizenbaum, word joseph
# Sentence from tf_Score notably successful natural language processing systems developed shrdlu natural language system working restricted blocks worlds restricted vocabularies eliza simulation rogerian psychotherapist written joseph weizenbaum, word weizenbaum
# ['using', 'information', 'thought', 'emotion', 'eliza', 'provided', 'interaction']
# Sentence from tf_Score using almost information human thought emotion eliza sometimes provided startlingly human like interaction, word using
# Sentence from tf_Score using almost information human thought emotion eliza sometimes provided startlingly human like interaction, word information
# Sentence from tf_Score using almost information human thought emotion eliza sometimes provided startlingly human like interaction, word thought
# Sentence from tf_Score using almost information human thought emotion eliza sometimes provided startlingly human like interaction, word emotion
# Sentence from tf_Score using almost information human thought emotion eliza sometimes provided startlingly human like interaction, word eliza
# Sentence from tf_Score using almost information human thought emotion eliza sometimes provided startlingly human like interaction, word provided
# Sentence from tf_Score using almost information human thought emotion eliza sometimes provided startlingly human like interaction, word interaction
# ['patient', 'exceeded', 'knowledge', 'base', 'eliza', 'provide', 'response', 'example', 'responding', 'head', 'hurts', 'say', 'head', 'hurts']
# Sentence from tf_Score patient exceeded small knowledge base eliza might provide generic response example responding head hurts say head hurts, word patient
# Sentence from tf_Score patient exceeded small knowledge base eliza might provide generic response example responding head hurts say head hurts, word exceeded
# Sentence from tf_Score patient exceeded small knowledge base eliza might provide generic response example responding head hurts say head hurts, word knowledge
# Sentence from tf_Score patient exceeded small knowledge base eliza might provide generic response example responding head hurts say head hurts, word base
# Sentence from tf_Score patient exceeded small knowledge base eliza might provide generic response example responding head hurts say head hurts, word eliza
# Sentence from tf_Score patient exceeded small knowledge base eliza might provide generic response example responding head hurts say head hurts, word provide
# Sentence from tf_Score patient exceeded small knowledge base eliza might provide generic response example responding head hurts say head hurts, word response
# Sentence from tf_Score patient exceeded small knowledge base eliza might provide generic response example responding head hurts say head hurts, word example
# Sentence from tf_Score patient exceeded small knowledge base eliza might provide generic response example responding head hurts say head hurts, word responding
# Sentence from tf_Score patient exceeded small knowledge base eliza might provide generic response example responding head hurts say head hurts, word head
# Sentence from tf_Score patient exceeded small knowledge base eliza might provide generic response example responding head hurts say head hurts, word hurt
# Sentence from tf_Score patient exceeded small knowledge base eliza might provide generic response example responding head hurts say head hurts, word say
# Sentence from tf_Score patient exceeded small knowledge base eliza might provide generic response example responding head hurts say head hurts, word head
# Sentence from tf_Score patient exceeded small knowledge base eliza might provide generic response example responding head hurts say head hurts, word hurt
# ['programmers', 'began', 'ontologies', 'structured', 'world', 'information', 'computer', 'data']
# Sentence from tf_Score many programmers began write conceptual ontologies structured real world information computer understandable data, word programmer
# Sentence from tf_Score many programmers began write conceptual ontologies structured real world information computer understandable data, word began
# Sentence from tf_Score many programmers began write conceptual ontologies structured real world information computer understandable data, word ontology
# Sentence from tf_Score many programmers began write conceptual ontologies structured real world information computer understandable data, word structured
# Sentence from tf_Score many programmers began write conceptual ontologies structured real world information computer understandable data, word world
# Sentence from tf_Score many programmers began write conceptual ontologies structured real world information computer understandable data, word information
# Sentence from tf_Score many programmers began write conceptual ontologies structured real world information computer understandable data, word computer
# Sentence from tf_Score many programmers began write conceptual ontologies structured real world information computer understandable data, word data
# ['examples', 'margie', 'sam', 'cullingford', 'pam', 'talespin', 'meehan', 'qualm', 'lehnert', 'politics', 'carbonell', 'plot', 'units', 'lehnert']
# Sentence from tf_Score examples margie schank sam cullingford pam wilensky talespin meehan qualm lehnert politics carbonell plot units lehnert, word example
# Sentence from tf_Score examples margie schank sam cullingford pam wilensky talespin meehan qualm lehnert politics carbonell plot units lehnert, word margie
# Sentence from tf_Score examples margie schank sam cullingford pam wilensky talespin meehan qualm lehnert politics carbonell plot units lehnert, word sam
# Sentence from tf_Score examples margie schank sam cullingford pam wilensky talespin meehan qualm lehnert politics carbonell plot units lehnert, word cullingford
# Sentence from tf_Score examples margie schank sam cullingford pam wilensky talespin meehan qualm lehnert politics carbonell plot units lehnert, word pam
# Sentence from tf_Score examples margie schank sam cullingford pam wilensky talespin meehan qualm lehnert politics carbonell plot units lehnert, word talespin
# Sentence from tf_Score examples margie schank sam cullingford pam wilensky talespin meehan qualm lehnert politics carbonell plot units lehnert, word meehan
# Sentence from tf_Score examples margie schank sam cullingford pam wilensky talespin meehan qualm lehnert politics carbonell plot units lehnert, word qualm
# Sentence from tf_Score examples margie schank sam cullingford pam wilensky talespin meehan qualm lehnert politics carbonell plot units lehnert, word lehnert
# Sentence from tf_Score examples margie schank sam cullingford pam wilensky talespin meehan qualm lehnert politics carbonell plot units lehnert, word politics
# Sentence from tf_Score examples margie schank sam cullingford pam wilensky talespin meehan qualm lehnert politics carbonell plot units lehnert, word carbonell
# Sentence from tf_Score examples margie schank sam cullingford pam wilensky talespin meehan qualm lehnert politics carbonell plot units lehnert, word plot
# Sentence from tf_Score examples margie schank sam cullingford pam wilensky talespin meehan qualm lehnert politics carbonell plot units lehnert, word unit
# Sentence from tf_Score examples margie schank sam cullingford pam wilensky talespin meehan qualm lehnert politics carbonell plot units lehnert, word lehnert
# ['time', 'chatterbots', 'written', 'including', 'parry', 'racter', 'jabberwacky']
# Sentence from tf_Score time many chatterbots written including parry racter jabberwacky, word time
# Sentence from tf_Score time many chatterbots written including parry racter jabberwacky, word chatterbots
# Sentence from tf_Score time many chatterbots written including parry racter jabberwacky, word written
# Sentence from tf_Score time many chatterbots written including parry racter jabberwacky, word including
# Sentence from tf_Score time many chatterbots written including parry racter jabberwacky, word parry
# Sentence from tf_Score time many chatterbots written including parry racter jabberwacky, word racter
# Sentence from tf_Score time many chatterbots written including parry racter jabberwacky, word jabberwacky
# ['language', 'processing', 'systems', 'based', 'sets', 'hand', 'written', 'rules']
# Sentence from tf_Score natural language processing systems based complex sets hand written rules, word language
# Sentence from tf_Score natural language processing systems based complex sets hand written rules, word processing
# Sentence from tf_Score natural language processing systems based complex sets hand written rules, word system
# Sentence from tf_Score natural language processing systems based complex sets hand written rules, word based
# Sentence from tf_Score natural language processing systems based complex sets hand written rules, word set
# Sentence from tf_Score natural language processing systems based complex sets hand written rules, word hand
# Sentence from tf_Score natural language processing systems based complex sets hand written rules, word written
# Sentence from tf_Score natural language processing systems based complex sets hand written rules, word rule
# ['starting', 'revolution', 'language', 'processing', 'introduction', 'machine', 'learning', 'language', 'processing']
# Sentence from tf_Score starting late however revolution natural language processing introduction machine learning algorithms language processing, word starting
# Sentence from tf_Score starting late however revolution natural language processing introduction machine learning algorithms language processing, word revolution
# Sentence from tf_Score starting late however revolution natural language processing introduction machine learning algorithms language processing, word language
# Sentence from tf_Score starting late however revolution natural language processing introduction machine learning algorithms language processing, word processing
# Sentence from tf_Score starting late however revolution natural language processing introduction machine learning algorithms language processing, word introduction
# Sentence from tf_Score starting late however revolution natural language processing introduction machine learning algorithms language processing, word machine
# Sentence from tf_Score starting late however revolution natural language processing introduction machine learning algorithms language processing, word learning
# Sentence from tf_Score starting late however revolution natural language processing introduction machine learning algorithms language processing, word language
# Sentence from tf_Score starting late however revolution natural language processing introduction machine learning algorithms language processing, word processing
# ['increase', 'power', 'see', 'law', 'lessening', 'dominance', 'theories', 'linguistics', 'e', 'g']
# Sentence from tf_Score due steady increase computational power see moore law gradual lessening dominance chomskyan theories linguistics e g, word increase
# Sentence from tf_Score due steady increase computational power see moore law gradual lessening dominance chomskyan theories linguistics e g, word power
# Sentence from tf_Score due steady increase computational power see moore law gradual lessening dominance chomskyan theories linguistics e g, word see
# Sentence from tf_Score due steady increase computational power see moore law gradual lessening dominance chomskyan theories linguistics e g, word law
# Sentence from tf_Score due steady increase computational power see moore law gradual lessening dominance chomskyan theories linguistics e g, word lessening
# Sentence from tf_Score due steady increase computational power see moore law gradual lessening dominance chomskyan theories linguistics e g, word dominance
# Sentence from tf_Score due steady increase computational power see moore law gradual lessening dominance chomskyan theories linguistics e g, word theory
# Sentence from tf_Score due steady increase computational power see moore law gradual lessening dominance chomskyan theories linguistics e g, word linguistics
# ['grammar', 'underpinnings', 'discouraged', 'sort', 'corpus', 'linguistics', 'underlies', 'machine', 'learning', 'approach', 'language', 'processing']
# Sentence from tf_Score transformational grammar whose theoretical underpinnings discouraged sort corpus linguistics underlies machine learning approach language processing, word grammar
# Sentence from tf_Score transformational grammar whose theoretical underpinnings discouraged sort corpus linguistics underlies machine learning approach language processing, word underpinnings
# Sentence from tf_Score transformational grammar whose theoretical underpinnings discouraged sort corpus linguistics underlies machine learning approach language processing, word discouraged
# Sentence from tf_Score transformational grammar whose theoretical underpinnings discouraged sort corpus linguistics underlies machine learning approach language processing, word sort
# Sentence from tf_Score transformational grammar whose theoretical underpinnings discouraged sort corpus linguistics underlies machine learning approach language processing, word corpus
# Sentence from tf_Score transformational grammar whose theoretical underpinnings discouraged sort corpus linguistics underlies machine learning approach language processing, word linguistics
# Sentence from tf_Score transformational grammar whose theoretical underpinnings discouraged sort corpus linguistics underlies machine learning approach language processing, word underlies
# Sentence from tf_Score transformational grammar whose theoretical underpinnings discouraged sort corpus linguistics underlies machine learning approach language processing, word machine
# Sentence from tf_Score transformational grammar whose theoretical underpinnings discouraged sort corpus linguistics underlies machine learning approach language processing, word learning
# Sentence from tf_Score transformational grammar whose theoretical underpinnings discouraged sort corpus linguistics underlies machine learning approach language processing, word approach
# Sentence from tf_Score transformational grammar whose theoretical underpinnings discouraged sort corpus linguistics underlies machine learning approach language processing, word language
# Sentence from tf_Score transformational grammar whose theoretical underpinnings discouraged sort corpus linguistics underlies machine learning approach language processing, word processing
# ['used', 'machine', 'learning', 'decision', 'trees', 'produced', 'systems', 'rules', 'existing', 'hand', 'written', 'rules']
# Sentence from tf_Score earliest used machine learning algorithms decision trees produced systems hard rules similar existing hand written rules, word used
# Sentence from tf_Score earliest used machine learning algorithms decision trees produced systems hard rules similar existing hand written rules, word machine
# Sentence from tf_Score earliest used machine learning algorithms decision trees produced systems hard rules similar existing hand written rules, word learning
# Sentence from tf_Score earliest used machine learning algorithms decision trees produced systems hard rules similar existing hand written rules, word decision
# Sentence from tf_Score earliest used machine learning algorithms decision trees produced systems hard rules similar existing hand written rules, word tree
# Sentence from tf_Score earliest used machine learning algorithms decision trees produced systems hard rules similar existing hand written rules, word produced
# Sentence from tf_Score earliest used machine learning algorithms decision trees produced systems hard rules similar existing hand written rules, word system
# Sentence from tf_Score earliest used machine learning algorithms decision trees produced systems hard rules similar existing hand written rules, word rule
# Sentence from tf_Score earliest used machine learning algorithms decision trees produced systems hard rules similar existing hand written rules, word existing
# Sentence from tf_Score earliest used machine learning algorithms decision trees produced systems hard rules similar existing hand written rules, word hand
# Sentence from tf_Score earliest used machine learning algorithms decision trees produced systems hard rules similar existing hand written rules, word written
# Sentence from tf_Score earliest used machine learning algorithms decision trees produced systems hard rules similar existing hand written rules, word rule
# ['part', 'speech', 'tagging', 'introduced', 'markov', 'models', 'language', 'processing', 'research', 'focused', 'models', 'make', 'decisions', 'based', 'attaching', 'valued', 'weights', 'features', 'making', 'input', 'data']
# Sentence from tf_Score however part speech tagging introduced use hidden markov models natural language processing increasingly research focused statistical models make soft probabilistic decisions based attaching real valued weights features making input data, word part
# Sentence from tf_Score however part speech tagging introduced use hidden markov models natural language processing increasingly research focused statistical models make soft probabilistic decisions based attaching real valued weights features making input data, word speech
# Sentence from tf_Score however part speech tagging introduced use hidden markov models natural language processing increasingly research focused statistical models make soft probabilistic decisions based attaching real valued weights features making input data, word tagging
# Sentence from tf_Score however part speech tagging introduced use hidden markov models natural language processing increasingly research focused statistical models make soft probabilistic decisions based attaching real valued weights features making input data, word introduced
# Sentence from tf_Score however part speech tagging introduced use hidden markov models natural language processing increasingly research focused statistical models make soft probabilistic decisions based attaching real valued weights features making input data, word markov
# Sentence from tf_Score however part speech tagging introduced use hidden markov models natural language processing increasingly research focused statistical models make soft probabilistic decisions based attaching real valued weights features making input data, word model
# Sentence from tf_Score however part speech tagging introduced use hidden markov models natural language processing increasingly research focused statistical models make soft probabilistic decisions based attaching real valued weights features making input data, word language
# Sentence from tf_Score however part speech tagging introduced use hidden markov models natural language processing increasingly research focused statistical models make soft probabilistic decisions based attaching real valued weights features making input data, word processing
# Sentence from tf_Score however part speech tagging introduced use hidden markov models natural language processing increasingly research focused statistical models make soft probabilistic decisions based attaching real valued weights features making input data, word research
# Sentence from tf_Score however part speech tagging introduced use hidden markov models natural language processing increasingly research focused statistical models make soft probabilistic decisions based attaching real valued weights features making input data, word focused
# Sentence from tf_Score however part speech tagging introduced use hidden markov models natural language processing increasingly research focused statistical models make soft probabilistic decisions based attaching real valued weights features making input data, word model
# Sentence from tf_Score however part speech tagging introduced use hidden markov models natural language processing increasingly research focused statistical models make soft probabilistic decisions based attaching real valued weights features making input data, word make
# Sentence from tf_Score however part speech tagging introduced use hidden markov models natural language processing increasingly research focused statistical models make soft probabilistic decisions based attaching real valued weights features making input data, word decision
# Sentence from tf_Score however part speech tagging introduced use hidden markov models natural language processing increasingly research focused statistical models make soft probabilistic decisions based attaching real valued weights features making input data, word based
# Sentence from tf_Score however part speech tagging introduced use hidden markov models natural language processing increasingly research focused statistical models make soft probabilistic decisions based attaching real valued weights features making input data, word attaching
# Sentence from tf_Score however part speech tagging introduced use hidden markov models natural language processing increasingly research focused statistical models make soft probabilistic decisions based attaching real valued weights features making input data, word valued
# Sentence from tf_Score however part speech tagging introduced use hidden markov models natural language processing increasingly research focused statistical models make soft probabilistic decisions based attaching real valued weights features making input data, word weight
# Sentence from tf_Score however part speech tagging introduced use hidden markov models natural language processing increasingly research focused statistical models make soft probabilistic decisions based attaching real valued weights features making input data, word feature
# Sentence from tf_Score however part speech tagging introduced use hidden markov models natural language processing increasingly research focused statistical models make soft probabilistic decisions based attaching real valued weights features making input data, word making
# Sentence from tf_Score however part speech tagging introduced use hidden markov models natural language processing increasingly research focused statistical models make soft probabilistic decisions based attaching real valued weights features making input data, word input
# Sentence from tf_Score however part speech tagging introduced use hidden markov models natural language processing increasingly research focused statistical models make soft probabilistic decisions based attaching real valued weights features making input data, word data
# ['cache', 'language', 'models', 'recognition', 'systems', 'rely', 'models']
# Sentence from tf_Score cache language models upon many speech recognition systems rely examples statistical models, word cache
# Sentence from tf_Score cache language models upon many speech recognition systems rely examples statistical models, word language
# Sentence from tf_Score cache language models upon many speech recognition systems rely examples statistical models, word model
# Sentence from tf_Score cache language models upon many speech recognition systems rely examples statistical models, word recognition
# Sentence from tf_Score cache language models upon many speech recognition systems rely examples statistical models, word system
# Sentence from tf_Score cache language models upon many speech recognition systems rely examples statistical models, word rely
# Sentence from tf_Score cache language models upon many speech recognition systems rely examples statistical models, word model
# ['models', 'robust', 'given', 'input', 'contains', 'errors', 'world', 'data', 'produce', 'results', 'integrated', 'system', 'comprising', 'subtasks']
# Sentence from tf_Score models generally robust given unfamiliar input especially input contains errors common real world data produce reliable results integrated larger system comprising multiple subtasks, word model
# Sentence from tf_Score models generally robust given unfamiliar input especially input contains errors common real world data produce reliable results integrated larger system comprising multiple subtasks, word robust
# Sentence from tf_Score models generally robust given unfamiliar input especially input contains errors common real world data produce reliable results integrated larger system comprising multiple subtasks, word given
# Sentence from tf_Score models generally robust given unfamiliar input especially input contains errors common real world data produce reliable results integrated larger system comprising multiple subtasks, word input
# Sentence from tf_Score models generally robust given unfamiliar input especially input contains errors common real world data produce reliable results integrated larger system comprising multiple subtasks, word contains
# Sentence from tf_Score models generally robust given unfamiliar input especially input contains errors common real world data produce reliable results integrated larger system comprising multiple subtasks, word error
# Sentence from tf_Score models generally robust given unfamiliar input especially input contains errors common real world data produce reliable results integrated larger system comprising multiple subtasks, word world
# Sentence from tf_Score models generally robust given unfamiliar input especially input contains errors common real world data produce reliable results integrated larger system comprising multiple subtasks, word data
# Sentence from tf_Score models generally robust given unfamiliar input especially input contains errors common real world data produce reliable results integrated larger system comprising multiple subtasks, word produce
# Sentence from tf_Score models generally robust given unfamiliar input especially input contains errors common real world data produce reliable results integrated larger system comprising multiple subtasks, word result
# Sentence from tf_Score models generally robust given unfamiliar input especially input contains errors common real world data produce reliable results integrated larger system comprising multiple subtasks, word integrated
# Sentence from tf_Score models generally robust given unfamiliar input especially input contains errors common real world data produce reliable results integrated larger system comprising multiple subtasks, word system
# Sentence from tf_Score models generally robust given unfamiliar input especially input contains errors common real world data produce reliable results integrated larger system comprising multiple subtasks, word comprising
# Sentence from tf_Score models generally robust given unfamiliar input especially input contains errors common real world data produce reliable results integrated larger system comprising multiple subtasks, word subtasks
# ...
# Sentence from tf_Score leads second defining aspect cognitive task nlp namely probabilistic context free grammar pcfg enables cognitive nlp algorithms assign relative measures meaning word phrase sentence piece text based information presented piece text analyzed, word context
# Sentence from tf_Score leads second defining aspect cognitive task nlp namely probabilistic context free grammar pcfg enables cognitive nlp algorithms assign relative measures meaning word phrase sentence piece text based information presented piece text analyzed, word grammar
# Sentence from tf_Score leads second defining aspect cognitive task nlp namely probabilistic context free grammar pcfg enables cognitive nlp algorithms assign relative measures meaning word phrase sentence piece text based information presented piece text analyzed, word pcfg
# Sentence from tf_Score leads second defining aspect cognitive task nlp namely probabilistic context free grammar pcfg enables cognitive nlp algorithms assign relative measures meaning word phrase sentence piece text based information presented piece text analyzed, word enables
# Sentence from tf_Score leads second defining aspect cognitive task nlp namely probabilistic context free grammar pcfg enables cognitive nlp algorithms assign relative measures meaning word phrase sentence piece text based information presented piece text analyzed, word nlp
# Sentence from tf_Score leads second defining aspect cognitive task nlp namely probabilistic context free grammar pcfg enables cognitive nlp algorithms assign relative measures meaning word phrase sentence piece text based information presented piece text analyzed, word algorithm
# Sentence from tf_Score leads second defining aspect cognitive task nlp namely probabilistic context free grammar pcfg enables cognitive nlp algorithms assign relative measures meaning word phrase sentence piece text based information presented piece text analyzed, word measure
# Sentence from tf_Score leads second defining aspect cognitive task nlp namely probabilistic context free grammar pcfg enables cognitive nlp algorithms assign relative measures meaning word phrase sentence piece text based information presented piece text analyzed, word meaning
# Sentence from tf_Score leads second defining aspect cognitive task nlp namely probabilistic context free grammar pcfg enables cognitive nlp algorithms assign relative measures meaning word phrase sentence piece text based information presented piece text analyzed, word word
# Sentence from tf_Score leads second defining aspect cognitive task nlp namely probabilistic context free grammar pcfg enables cognitive nlp algorithms assign relative measures meaning word phrase sentence piece text based information presented piece text analyzed, word phrase
# Sentence from tf_Score leads second defining aspect cognitive task nlp namely probabilistic context free grammar pcfg enables cognitive nlp algorithms assign relative measures meaning word phrase sentence piece text based information presented piece text analyzed, word sentence
# Sentence from tf_Score leads second defining aspect cognitive task nlp namely probabilistic context free grammar pcfg enables cognitive nlp algorithms assign relative measures meaning word phrase sentence piece text based information presented piece text analyzed, word piece
# Sentence from tf_Score leads second defining aspect cognitive task nlp namely probabilistic context free grammar pcfg enables cognitive nlp algorithms assign relative measures meaning word phrase sentence piece text based information presented piece text analyzed, word text
# Sentence from tf_Score leads second defining aspect cognitive task nlp namely probabilistic context free grammar pcfg enables cognitive nlp algorithms assign relative measures meaning word phrase sentence piece text based information presented piece text analyzed, word based
# Sentence from tf_Score leads second defining aspect cognitive task nlp namely probabilistic context free grammar pcfg enables cognitive nlp algorithms assign relative measures meaning word phrase sentence piece text based information presented piece text analyzed, word information
# Sentence from tf_Score leads second defining aspect cognitive task nlp namely probabilistic context free grammar pcfg enables cognitive nlp algorithms assign relative measures meaning word phrase sentence piece text based information presented piece text analyzed, word presented
# Sentence from tf_Score leads second defining aspect cognitive task nlp namely probabilistic context free grammar pcfg enables cognitive nlp algorithms assign relative measures meaning word phrase sentence piece text based information presented piece text analyzed, word piece
# Sentence from tf_Score leads second defining aspect cognitive task nlp namely probabilistic context free grammar pcfg enables cognitive nlp algorithms assign relative measures meaning word phrase sentence piece text based information presented piece text analyzed, word text
# Sentence from tf_Score leads second defining aspect cognitive task nlp namely probabilistic context free grammar pcfg enables cognitive nlp algorithms assign relative measures meaning word phrase sentence piece text based information presented piece text analyzed, word analyzed
# ['equation', 'algorithms', 'presented', 'patent', 'rmm', 'measure', 'meaning', 'block', 'text', 'sentence', 'phrase', 'word', 'number', 'tokens', 'analyzed', 'pmm', 'measure', 'meaning', 'based', 'corpora', 'number', 'tokens', 'analyzed', 'location', 'token', 'sequence', 'n', 'tokens', 'probability', 'function', 'language']
# Sentence from tf_Score mathematical equation algorithms presented us patent rmm relative measure meaning token block text sentence phrase word n number tokens analyzed pmm probable measure meaning based corpora n one less number tokens analyzed location token along sequence n tokens pf probability function specific language, word equation
# Sentence from tf_Score mathematical equation algorithms presented us patent rmm relative measure meaning token block text sentence phrase word n number tokens analyzed pmm probable measure meaning based corpora n one less number tokens analyzed location token along sequence n tokens pf probability function specific language, word algorithm
# Sentence from tf_Score mathematical equation algorithms presented us patent rmm relative measure meaning token block text sentence phrase word n number tokens analyzed pmm probable measure meaning based corpora n one less number tokens analyzed location token along sequence n tokens pf probability function specific language, word presented
# Sentence from tf_Score mathematical equation algorithms presented us patent rmm relative measure meaning token block text sentence phrase word n number tokens analyzed pmm probable measure meaning based corpora n one less number tokens analyzed location token along sequence n tokens pf probability function specific language, word patent
# Sentence from tf_Score mathematical equation algorithms presented us patent rmm relative measure meaning token block text sentence phrase word n number tokens analyzed pmm probable measure meaning based corpora n one less number tokens analyzed location token along sequence n tokens pf probability function specific language, word rmm
# Sentence from tf_Score mathematical equation algorithms presented us patent rmm relative measure meaning token block text sentence phrase word n number tokens analyzed pmm probable measure meaning based corpora n one less number tokens analyzed location token along sequence n tokens pf probability function specific language, word measure
# Sentence from tf_Score mathematical equation algorithms presented us patent rmm relative measure meaning token block text sentence phrase word n number tokens analyzed pmm probable measure meaning based corpora n one less number tokens analyzed location token along sequence n tokens pf probability function specific language, word meaning
# Sentence from tf_Score mathematical equation algorithms presented us patent rmm relative measure meaning token block text sentence phrase word n number tokens analyzed pmm probable measure meaning based corpora n one less number tokens analyzed location token along sequence n tokens pf probability function specific language, word block
# Sentence from tf_Score mathematical equation algorithms presented us patent rmm relative measure meaning token block text sentence phrase word n number tokens analyzed pmm probable measure meaning based corpora n one less number tokens analyzed location token along sequence n tokens pf probability function specific language, word text
# Sentence from tf_Score mathematical equation algorithms presented us patent rmm relative measure meaning token block text sentence phrase word n number tokens analyzed pmm probable measure meaning based corpora n one less number tokens analyzed location token along sequence n tokens pf probability function specific language, word sentence
# Sentence from tf_Score mathematical equation algorithms presented us patent rmm relative measure meaning token block text sentence phrase word n number tokens analyzed pmm probable measure meaning based corpora n one less number tokens analyzed location token along sequence n tokens pf probability function specific language, word phrase
# Sentence from tf_Score mathematical equation algorithms presented us patent rmm relative measure meaning token block text sentence phrase word n number tokens analyzed pmm probable measure meaning based corpora n one less number tokens analyzed location token along sequence n tokens pf probability function specific language, word word
# Sentence from tf_Score mathematical equation algorithms presented us patent rmm relative measure meaning token block text sentence phrase word n number tokens analyzed pmm probable measure meaning based corpora n one less number tokens analyzed location token along sequence n tokens pf probability function specific language, word number
# Sentence from tf_Score mathematical equation algorithms presented us patent rmm relative measure meaning token block text sentence phrase word n number tokens analyzed pmm probable measure meaning based corpora n one less number tokens analyzed location token along sequence n tokens pf probability function specific language, word token
# Sentence from tf_Score mathematical equation algorithms presented us patent rmm relative measure meaning token block text sentence phrase word n number tokens analyzed pmm probable measure meaning based corpora n one less number tokens analyzed location token along sequence n tokens pf probability function specific language, word analyzed
# Sentence from tf_Score mathematical equation algorithms presented us patent rmm relative measure meaning token block text sentence phrase word n number tokens analyzed pmm probable measure meaning based corpora n one less number tokens analyzed location token along sequence n tokens pf probability function specific language, word pmm
# Sentence from tf_Score mathematical equation algorithms presented us patent rmm relative measure meaning token block text sentence phrase word n number tokens analyzed pmm probable measure meaning based corpora n one less number tokens analyzed location token along sequence n tokens pf probability function specific language, word measure
# Sentence from tf_Score mathematical equation algorithms presented us patent rmm relative measure meaning token block text sentence phrase word n number tokens analyzed pmm probable measure meaning based corpora n one less number tokens analyzed location token along sequence n tokens pf probability function specific language, word meaning
# Sentence from tf_Score mathematical equation algorithms presented us patent rmm relative measure meaning token block text sentence phrase word n number tokens analyzed pmm probable measure meaning based corpora n one less number tokens analyzed location token along sequence n tokens pf probability function specific language, word based
# Sentence from tf_Score mathematical equation algorithms presented us patent rmm relative measure meaning token block text sentence phrase word n number tokens analyzed pmm probable measure meaning based corpora n one less number tokens analyzed location token along sequence n tokens pf probability function specific language, word corpus
# Sentence from tf_Score mathematical equation algorithms presented us patent rmm relative measure meaning token block text sentence phrase word n number tokens analyzed pmm probable measure meaning based corpora n one less number tokens analyzed location token along sequence n tokens pf probability function specific language, word number
# Sentence from tf_Score mathematical equation algorithms presented us patent rmm relative measure meaning token block text sentence phrase word n number tokens analyzed pmm probable measure meaning based corpora n one less number tokens analyzed location token along sequence n tokens pf probability function specific language, word token
# Sentence from tf_Score mathematical equation algorithms presented us patent rmm relative measure meaning token block text sentence phrase word n number tokens analyzed pmm probable measure meaning based corpora n one less number tokens analyzed location token along sequence n tokens pf probability function specific language, word analyzed
# Sentence from tf_Score mathematical equation algorithms presented us patent rmm relative measure meaning token block text sentence phrase word n number tokens analyzed pmm probable measure meaning based corpora n one less number tokens analyzed location token along sequence n tokens pf probability function specific language, word location
# Sentence from tf_Score mathematical equation algorithms presented us patent rmm relative measure meaning token block text sentence phrase word n number tokens analyzed pmm probable measure meaning based corpora n one less number tokens analyzed location token along sequence n tokens pf probability function specific language, word token
# Sentence from tf_Score mathematical equation algorithms presented us patent rmm relative measure meaning token block text sentence phrase word n number tokens analyzed pmm probable measure meaning based corpora n one less number tokens analyzed location token along sequence n tokens pf probability function specific language, word sequence
# Sentence from tf_Score mathematical equation algorithms presented us patent rmm relative measure meaning token block text sentence phrase word n number tokens analyzed pmm probable measure meaning based corpora n one less number tokens analyzed location token along sequence n tokens pf probability function specific language, word token
# Sentence from tf_Score mathematical equation algorithms presented us patent rmm relative measure meaning token block text sentence phrase word n number tokens analyzed pmm probable measure meaning based corpora n one less number tokens analyzed location token along sequence n tokens pf probability function specific language, word probability
# Sentence from tf_Score mathematical equation algorithms presented us patent rmm relative measure meaning token block text sentence phrase word n number tokens analyzed pmm probable measure meaning based corpora n one less number tokens analyzed location token along sequence n tokens pf probability function specific language, word function
# Sentence from tf_Score mathematical equation algorithms presented us patent rmm relative measure meaning token block text sentence phrase word n number tokens analyzed pmm probable measure meaning based corpora n one less number tokens analyzed location token along sequence n tokens pf probability function specific language, word language

# %%
sentence_with_importance
# Out:
# [(4, 0.23232634653228468),
#  (28, 0.21892812769144607),
#  (13, 0.20746211688975733),
#  (58, 0.20202918623695887),
#  (11, 0.19234160807081968),
#  (53, 0.17489080973555177),
#  (14, 0.17406056206694742),
#  (54, 0.17030156630763374),
#  (50, 0.15423543733361786),
#  (34, 0.14881602197169777),
#  (57, 0.14697362421347107),
#  (46, 0.14522546344791484),
#  (47, 0.14440638303112777),
#  (32, 0.1304854946392828),
#  (48, 0.12627581825184214),
#  (39, 0.12008681075859537),
#  (31, 0.11456260772155663),
#  (44, 0.10431635745582162),
#  (51, 0.10254232713511141),
#  (9, 0.09955207832523374),
#  (56, 0.09752097956701519),
#  (17, 0.09519798240755672),
#  (18, 0.09510754541696155),
#  (8, 0.09438905527491177),
#  (35, 0.09410913577934854),
#  (10, 0.09399796899272599),
#  (7, 0.0928877371219802),
#  (3, 0.0890596072672405),
#  (22, 0.08583783182454034),
#  (16, 0.08574419258480087),
#  (6, 0.08572623219366991),
#  (52, 0.08571637858714996),
#  (26, 0.08287705617503555),
#  (1, 0.08252294065956703),
#  (5, 0.08188868818302741),
#  (20, 0.0812769585063358),
#  (2, 0.0805297183648698),
#  (25, 0.07444213826450524),
#  (33, 0.07336139609907565),
#  (43, 0.0732679676030128),
#  (55, 0.07286013083175762),
#  (49, 0.07183824964133058),
#  (27, 0.07024473947864567),
#  (30, 0.06921984643491891),
#  (19, 0.06856882691576399),
#  (41, 0.06798355494463758),
#  (12, 0.06789453931415021),
#  (23, 0.06743305867130303),
#  (24, 0.06742533617541319),
#  (36, 0.0662549556339206),
#  (42, 0.06050413715228141),
#  (45, 0.06011419037614077),
#  (21, 0.05990826354861305),
#  (29, 0.05643158643494593),
#  (15, 0.05627219187450487),
#  (37, 0.05526248584131826),
#  (38, 0.04439242700957725),
#  (40, 0.030009869981653982)]

# %%
input_user = int(input('Percentage of information to retain(in percent):'))
no_of_sentences = int((input_user * len(clean_sentences))/100)
print(no_of_sentences)

cnt = 0
summary = []
sentence_no = []
for word_prob in sentence_with_importance:
    if cnt < no_of_sentences:
        sentence_no.append(word_prob[0])
        cnt = cnt+1
    else:
        break
sentence_no.sort()
#print(sentence_no[:5])
cnt = 1
for sentence in sentences:
    if cnt in sentence_no:
        print(sentence)
        summary.append(sentence)
    cnt = cnt+1
summary = " ".join(summary)
print("\n")
print("Summary:")
print(summary)
# Out:
# Percentage of information to retain(in percent):30
# 17
# In 1950, Alan Turing published an article titled "Computing Machinery and Intelligence" which proposed what is now called the Turing test as a criterion of intelligence[clarification needed].
# When the "patient" exceeded the very small knowledge base, ELIZA might provide a generic response, for example, responding to "My head hurts" with "Why do you say your head hurts?".
# Examples are MARGIE (Schank, 1975), SAM (Cullingford, 1978), PAM (Wilensky, 1978), TaleSpin (Meehan, 1976), QUALM (Lehnert, 1977), Politics (Carbonell, 1979), and Plot Units (Lehnert 1981).
# During this time, many chatterbots were written including PARRY, Racter, and Jabberwacky.
# Such algorithms can learn from data that has not been hand-annotated with the desired answers or using a combination of annotated and non-annotated data.
# In the 2010s, representation learning and deep neural network-style machine learning methods became widespread in natural language processing, due in part to a flurry of results showing that such techniques[4][5] can achieve state-of-the-art results in many natural language tasks, for example in language modeling,[6] parsing,[7][8] and many others.
# Popular techniques include the use of word embeddings to capture semantic properties of words, and an increase in end-to-end learning of a higher-level task (e.g., question answering) instead of relying on a pipeline of separate intermediate tasks (e.g., part-of-speech tagging and dependency parsing).
# For instance, the term neural machine translation (NMT) emphasizes the fact that deep learning-based approaches to machine translation directly learn sequence-to-sequence transformations, obviating the need for intermediate steps such as word alignment and language modeling that was used in statistical machine translation (SMT).
# These algorithms take as input a large set of "features" that are generated from the input data.
# A coarse division is given below.
# The first published work by an artificial intelligence was published in 2018, 1 the Road, marketed as a novel, contains sixty million words.
# Cognition refers to "the mental action or process of acquiring knowledge and understanding through thought, experience, and the senses.
# [20] Cognitive linguistics is an interdisciplinary branch of linguistics, combining knowledge and research from both psychology and linguistics.
# When used as a Comparative, as in “That is a big tree,” a likely inference of the intent of the author is that the author is using the word “big” to imply a statement about the tree being ”physically large” in comparison to other trees or the authors experience.
# When used as a Stative verb, as in ”Tomorrow is a big day”, a likely inference of the author’s intent it that ”big” is being used to imply ”importance”.
# This leads to the second defining aspect of this cognitive task of NLP, namely Probabilistic context-free grammar (PCFG) which enables cognitive NLP algorithms to assign relative measures of meaning  to a word, phrase, sentence or piece of text based on the information presented before and after the piece of text being analyzed.
# The mathematical equation for such algorithms is presented in US patent 9269353 :
# Where,
#      RMM, is the Relative Measure of Meaning
#      token, is any block of text, sentence, phrase or word
#      N, is the number of tokens being analyzed
#      PMM, is the Probable Measure of Meaning based on a corpora
#      n, is one less than the number of tokens being analyzed
#      d, is the location of the token along the sequence of n tokens
#      PF, is the Probability Function specific to a language
#
#
# Summary:
# In 1950, Alan Turing published an article titled "Computing Machinery and Intelligence" which proposed what is now called the Turing test as a criterion of intelligence[clarification needed]. When the "patient" exceeded the very small knowledge base, ELIZA might provide a generic response, for example, responding to "My head hurts" with "Why do you say your head hurts?". Examples are MARGIE (Schank, 1975), SAM (Cullingford, 1978), PAM (Wilensky, 1978), TaleSpin (Meehan, 1976), QUALM (Lehnert, 1977), Politics (Carbonell, 1979), and Plot Units (Lehnert 1981). During this time, many chatterbots were written including PARRY, Racter, and Jabberwacky. Such algorithms can learn from data that has not been hand-annotated with the desired answers or using a combination of annotated and non-annotated data. In the 2010s, representation learning and deep neural network-style machine learning methods became widespread in natural language processing, due in part to a flurry of results showing that such techniques[4][5] can achieve state-of-the-art results in many natural language tasks, for example in language modeling,[6] parsing,[7][8] and many others. Popular techniques include the use of word embeddings to capture semantic properties of words, and an increase in end-to-end learning of a higher-level task (e.g., question answering) instead of relying on a pipeline of separate intermediate tasks (e.g., part-of-speech tagging and dependency parsing). For instance, the term neural machine translation (NMT) emphasizes the fact that deep learning-based approaches to machine translation directly learn sequence-to-sequence transformations, obviating the need for intermediate steps such as word alignment and language modeling that was used in statistical machine translation (SMT). These algorithms take as input a large set of "features" that are generated from the input data. A coarse division is given below. The first published work by an artificial intelligence was published in 2018, 1 the Road, marketed as a novel, contains sixty million words. Cognition refers to "the mental action or process of acquiring knowledge and understanding through thought, experience, and the senses. [20] Cognitive linguistics is an interdisciplinary branch of linguistics, combining knowledge and research from both psychology and linguistics. When used as a Comparative, as in “That is a big tree,” a likely inference of the intent of the author is that the author is using the word “big” to imply a statement about the tree being ”physically large” in comparison to other trees or the authors experience. When used as a Stative verb, as in ”Tomorrow is a big day”, a likely inference of the author’s intent it that ”big” is being used to imply ”importance”. This leads to the second defining aspect of this cognitive task of NLP, namely Probabilistic context-free grammar (PCFG) which enables cognitive NLP algorithms to assign relative measures of meaning  to a word, phrase, sentence or piece of text based on the information presented before and after the piece of text being analyzed. The mathematical equation for such algorithms is presented in US patent 9269353 :
# Where,
#      RMM, is the Relative Measure of Meaning
#      token, is any block of text, sentence, phrase or word
#      N, is the number of tokens being analyzed
#      PMM, is the Probable Measure of Meaning based on a corpora
#      n, is one less than the number of tokens being analyzed
#      d, is the location of the token along the sequence of n tokens
#      PF, is the Probability Function specific to a language

# %%
clean_sentences[1]
# Out:
# 'russian player problems openly speaking recent interview said really hide feelings much'

# %%
input_user = int(input('Percentage of information to retain(in percent):'))
no_of_sentences = int((input_user * len(clean_sentences))/100)
print(no_of_sentences)

for sent in clean_sentences:
    sentenceimp =  sentence_importance(sent,word_freq,clean_sentences)
    sentence_with_importance[c] = sentenceimp
    c = c+1
    sentence_with_importance =  sorted(sentence_with_importance.items(), key=operator.itemgetter(1),reverse=True)
    cnt = 0
    summary = []
    sentence_no = []
    for word_prob in sentence_with_importance:
        if cnt < no_of_sentences:
            sentence_no.append(word_prob[0])
            cnt = cnt+1
        else:
            break
sentence_no.sort()
cnt = 1
for sentence in clean_sentences:
    if cnt in sentence_no:
        summary.append(sentence)
    cnt = cnt+1
summary = " ".join(summary)
print("\n")
print("Summary:")
print(summary)
outF = open('summary.txt',"w")
outF.write(summary)
# Out:
# Percentage of information to retain(in percent):
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-124-b51d539e0ded> in <module>
# ----> 1 input_user = int(input('Percentage of information to retain(in percent):'))
#       2 no_of_sentences = int((input_user * len(clean_sentences))/100)
#       3 print(no_of_sentences)
#       4
#       5 for sent in clean_sentences:
#
# ValueError: invalid literal for int() with base 10: ''

# %%
import nltk
import os
import re
import math
import operator
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
from nltk.tokenize import sent_tokenize,word_tokenize
nltk.download('averaged_perceptron_tagger')
Stopwords = set(stopwords.words('english'))
wordlemmatizer = WordNetLemmatizer()
def lemmatize_words(words):
    lemmatized_words = []
    for word in words:
        lemmatized_words.append(wordlemmatizer.lemmatize(word))
    return lemmatized_words
def stem_words(words):
    stemmed_words = []
    for word in words:
       stemmed_words.append(stemmer.stem(word))
    return stemmed_words
def remove_special_characters(text):
    regex = r'[^a-zA-Z0-9\s]'
    text = re.sub(regex,'',text)
    return text
def freq(words):
    words = [word.lower() for word in words]
    dict_freq = {}
    words_unique = []
    for word in words:
       if word not in words_unique:
           words_unique.append(word)
    for word in words_unique:
       dict_freq[word] = words.count(word)
    return dict_freq
def pos_tagging(text):
    pos_tag = nltk.pos_tag(text.split())
    pos_tagged_noun_verb = []
    for word,tag in pos_tag:
        if tag == "NN" or tag == "NNP" or tag == "NNS" or tag == "VB" or tag == "VBD" or tag == "VBG" or tag == "VBN" or tag == "VBP" or tag == "VBZ":
             pos_tagged_noun_verb.append(word)
    return pos_tagged_noun_verb
def tf_score(word,sentence):
    freq_sum = 0
    word_frequency_in_sentence = 0
    len_sentence = len(sentence)
    for word_in_sentence in sentence.split():
        if word == word_in_sentence:
            word_frequency_in_sentence = word_frequency_in_sentence + 1
    tf =  word_frequency_in_sentence/ len_sentence
    return tf
def idf_score(no_of_sentences,word,sentences):
    no_of_sentence_containing_word = 0
    for sentence in sentences:
        sentence = remove_special_characters(str(sentence))
        sentence = re.sub(r'\d+', '', sentence)
        sentence = sentence.split()
        sentence = [word for word in sentence if word.lower() not in Stopwords and len(word)>1]
        sentence = [word.lower() for word in sentence]
        sentence = [wordlemmatizer.lemmatize(word) for word in sentence]
        if word in sentence:
            no_of_sentence_containing_word = no_of_sentence_containing_word + 1
    idf = math.log10(no_of_sentences/no_of_sentence_containing_word)
    return idf
def tf_idf_score(tf,idf):
    return tf*idf
def word_tfidf(dict_freq,word,sentences,sentence):
    word_tfidf = []
    tf = tf_score(word,sentence)
    idf = idf_score(len(sentences),word,sentences)
    tf_idf = tf_idf_score(tf,idf)
    return tf_idf
def sentence_importance(sentence,dict_freq,sentences):
     sentence_score = 0
     sentence = remove_special_characters(str(sentence)) 
     sentence = re.sub(r'\d+', '', sentence)
     pos_tagged_sentence = [] 
     no_of_sentences = len(sentences)
     pos_tagged_sentence = pos_tagging(sentence)
     for word in pos_tagged_sentence:
          if word.lower() not in Stopwords and word not in Stopwords and len(word)>1: 
                word = word.lower()
                word = wordlemmatizer.lemmatize(word)
                sentence_score = sentence_score + word_tfidf(dict_freq,word,sentences,sentence)
     return sentence_score
#file = 'input.txt'
#file = open(file , 'r')
#text = file.read()
#tokenized_sentence = sent_tokenize(text)
#text = remove_special_characters(str(text))
#text = re.sub(r'\d+', '', text)
#tokenized_words_with_stopwords = word_tokenize(text)
#tokenized_words = [word for word in tokenized_words_with_stopwords if word not in Stopwords]
#tokenized_words = [word for word in tokenized_words if len(word) > 1]
#tokenized_words = [word.lower() for word in tokenized_words]
#tokenized_words = lemmatize_words(tokenized_words)
#word_freq = freq(tokenized_words)
input_user = int(input('Percentage of information to retain(in percent):'))
no_of_sentences = int((input_user * len(tokenized_sentence))/100)
print(no_of_sentences)
c = 1
sentence_with_importance = {}
for sent in tokenized_sentence:
    sentenceimp = sentence_importance(sent,word_freq,tokenized_sentence)
    sentence_with_importance[c] = sentenceimp
    c = c+1
sentence_with_importance = sorted(sentence_with_importance.items(), key=operator.itemgetter(1),reverse=True)
cnt = 0
summary = []
sentence_no = []
for word_prob in sentence_with_importance:
    if cnt < no_of_sentences:
        sentence_no.append(word_prob[0])
        cnt = cnt+1
    else:
      break
sentence_no.sort()
cnt = 1
for sentence in tokenized_sentence:
    if cnt in sentence_no:
       summary.append(sentence)
    cnt = cnt+1
summary = " ".join(summary)
print("\n")
print("Summary:")
print(summary)
outF = open('summary.txt',"w")
outF.write(summary)
